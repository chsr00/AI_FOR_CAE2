# %% [markdown]
# <a href="https://colab.research.google.com/github/chsr00/AI_FOR_CAE2/blob/main/AE_model_v2_1_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2 as cv
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow import shape,math
from tensorflow.keras import Input,layers,Model
from tensorflow.keras.losses import mse,binary_crossentropy
from tensorflow.keras.utils import plot_model

print(tf.__version__)
# Out:
# 2.12.0

# %% [markdown]
# 데이터 불러오기

# %%
#from google.colab import files

#uploaded = files.upload()

## 코드가 돌아가면 파일선택 버튼을 눌러서 upload할 파일 선택
#for fn in uploaded.keys():
#  print('User uploaded file "{name}" with length {length} bytes'.format(
#      name=fn, length=len(uploaded[fn])))

# !git clone https://github.com/chsr00/AI_FOR_CAE2.git
# Out:
# Cloning into 'AI_FOR_CAE2'...
# remote: Enumerating objects: 21, done.
# remote: Counting objects: 100% (21/21), done.
# remote: Compressing objects: 100% (19/19), done.
# remote: Total 21 (delta 6), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (21/21), 2.80 MiB | 6.88 MiB/s, done.
# Resolving deltas: 100% (6/6), done.

# %%
! mkdir data_3000
! unzip ./AI_FOR_CAE2/data_3000.zip
! pwd
#! ls -al
#! cd /content/AI_FOR_CAE2
#! ls -al
! mv *.jpg ./data_3000/
# !ls -al ./data_3000
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#   inflating: 26.5087.jpg
#   inflating: 26.5093.jpg
#   inflating: 26.5099.jpg
#   inflating: 26.51.jpg
#   inflating: 26.5105.jpg
#   inflating: 26.5109.jpg
#   inflating: 26.5133.jpg
#   inflating: 26.5169.jpg
#   inflating: 26.517.jpg
#   inflating: 26.5187.jpg
#   inflating: 26.5224.jpg
#   inflating: 26.5234.jpg
#   inflating: 26.5235.jpg
#   inflating: 26.5236.jpg
#   inflating: 26.5237.jpg
#   inflating: 26.5251.jpg
#   inflating: 26.5253.jpg
#   inflating: 26.5256.jpg
#   inflating: 26.5258.jpg
#   inflating: 26.5262.jpg
#   inflating: 26.527.jpg
#   inflating: 26.5291.jpg
#   inflating: 26.5293.jpg
#   inflating: 26.532.jpg
#   inflating: 26.5321.jpg
#   inflating: 26.5324.jpg
#   inflating: 26.5359.jpg
#   inflating: 26.5377.jpg
#   inflating: 26.5414.jpg
#   inflating: 26.5429.jpg
#   inflating: 26.5433.jpg
#   inflating: 26.5444.jpg
#   inflating: 26.5465.jpg
#   inflating: 26.548.jpg
#   inflating: 26.5483.jpg
#   inflating: 26.5488.jpg
#   inflating: 26.5492.jpg
#   inflating: 26.5521.jpg
#   inflating: 26.5528.jpg
#   inflating: 26.5532.jpg
#   inflating: 26.5545.jpg
#   inflating: 26.555.jpg
#   inflating: 26.5581.jpg
#   inflating: 26.559.jpg
#   inflating: 26.5601.jpg
#   inflating: 26.5611.jpg
#   inflating: 26.5612.jpg
#   inflating: 26.5615.jpg
#   inflating: 26.5658.jpg
#   inflating: 26.5659.jpg
#   inflating: 26.5693.jpg
#   inflating: 26.5699.jpg
#   inflating: 26.5706.jpg
#   inflating: 26.5708.jpg
#   inflating: 26.5717.jpg
#   inflating: 26.5756.jpg
#   inflating: 26.5757.jpg
#   inflating: 26.5761.jpg
#   inflating: 26.579.jpg
#   inflating: 26.5794.jpg
#   inflating: 26.5802.jpg
#   inflating: 26.5818.jpg
#   inflating: 28.4736.jpg
#   inflating: 28.474.jpg
#   inflating: 28.4744.jpg
#   inflating: 28.4778.jpg
#   inflating: 28.4787.jpg
#   inflating: 28.4794.jpg
#   inflating: 28.4798.jpg
#   inflating: 28.4815.jpg
#   inflating: 28.4826.jpg
#   inflating: 28.4842.jpg
#   inflating: 28.4854.jpg
#   inflating: 28.4867.jpg
#   inflating: 28.4868.jpg
#   inflating: 28.4871.jpg
#   inflating: 28.4877.jpg
#   inflating: 28.4889.jpg
#   inflating: 28.4923.jpg
#   inflating: 28.4932.jpg
#   inflating: 28.4953.jpg
#   inflating: 28.4955.jpg
#   inflating: 28.4958.jpg
#   inflating: 28.4977.jpg
#   inflating: 28.4984.jpg
#   inflating: 28.5014.jpg
#   inflating: 28.5034.jpg
#   inflating: 28.5053.jpg
# ...
# -rw-r--r-- 1 root root  1052 Jan 18  2020 29.167.jpg
# -rw-r--r-- 1 root root  1073 Jan 19  2020 29.1683.jpg
# -rw-r--r-- 1 root root  1008 Jan 19  2020 29.1726.jpg
# -rw-r--r-- 1 root root  1059 Jan 19  2020 29.1729.jpg
# -rw-r--r-- 1 root root  1041 Jan 19  2020 29.1738.jpg
# -rw-r--r-- 1 root root  1088 Jan 19  2020 29.1757.jpg
# -rw-r--r-- 1 root root   985 Jan 19  2020 29.1761.jpg
# -rw-r--r-- 1 root root  1044 Jan 19  2020 29.1762.jpg
# -rw-r--r-- 1 root root   999 Jan 19  2020 29.1775.jpg
# -rw-r--r-- 1 root root   992 Jan 19  2020 29.1787.jpg
# -rw-r--r-- 1 root root  1015 Jan 19  2020 29.1807.jpg
# -rw-r--r-- 1 root root  1005 Jan 19  2020 29.1812.jpg
# -rw-r--r-- 1 root root   962 Jan 19  2020 29.1826.jpg
# -rw-r--r-- 1 root root   984 Jan 19  2020 29.1827.jpg
# -rw-r--r-- 1 root root   997 Jan 19  2020 29.1828.jpg
# -rw-r--r-- 1 root root   955 Jan 19  2020 29.1831.jpg
# -rw-r--r-- 1 root root   911 Jan 19  2020 29.1896.jpg
# -rw-r--r-- 1 root root  1031 Jan 19  2020 29.1918.jpg
# -rw-r--r-- 1 root root  1055 Jan 18  2020 29.1951.jpg
# -rw-r--r-- 1 root root  1045 Jan 19  2020 29.1992.jpg
# -rw-r--r-- 1 root root  1034 Jan 19  2020 29.2001.jpg
# -rw-r--r-- 1 root root  1065 Jan 19  2020 29.2005.jpg
# -rw-r--r-- 1 root root   990 Jan 19  2020 29.2013.jpg
# -rw-r--r-- 1 root root  1072 Jan 19  2020 29.2014.jpg
# -rw-r--r-- 1 root root  1037 Jan 19  2020 29.2031.jpg
# -rw-r--r-- 1 root root   976 Jan 19  2020 29.2047.jpg
# -rw-r--r-- 1 root root  1053 Jan 19  2020 29.2071.jpg
# -rw-r--r-- 1 root root   982 Jan 19  2020 29.2073.jpg
# -rw-r--r-- 1 root root   990 Jan 19  2020 29.213.jpg
# -rw-r--r-- 1 root root  1052 Jan 19  2020 29.2145.jpg
# -rw-r--r-- 1 root root  1061 Jan 19  2020 29.2146.jpg
# -rw-r--r-- 1 root root   983 Jan 19  2020 29.2176.jpg
# -rw-r--r-- 1 root root  1036 Jan 19  2020 29.222.jpg
# -rw-r--r-- 1 root root  1039 Jan 19  2020 29.2245.jpg
# -rw-r--r-- 1 root root  1000 Jan 19  2020 29.2279.jpg
# -rw-r--r-- 1 root root   999 Jan 19  2020 29.2283.jpg
# -rw-r--r-- 1 root root   971 Jan 19  2020 29.2296.jpg
# -rw-r--r-- 1 root root  1039 Jan 19  2020 29.2307.jpg
# -rw-r--r-- 1 root root  1041 Jan 19  2020 29.2331.jpg
# -rw-r--r-- 1 root root  1010 Jan 19  2020 29.2332.jpg
# -rw-r--r-- 1 root root  1079 Jan 19  2020 29.2335.jpg
# -rw-r--r-- 1 root root   978 Jan 19  2020 29.2343.jpg
# -rw-r--r-- 1 root root  1045 Jan 19  2020 29.2369.jpg
# -rw-r--r-- 1 root root  1049 Jan 19  2020 29.2371.jpg
# -rw-r--r-- 1 root root  1021 Jan 18  2020 29.237.jpg
# -rw-r--r-- 1 root root  1074 Jan 19  2020 29.2386.jpg
# -rw-r--r-- 1 root root  1038 Jan 19  2020 29.2388.jpg
# -rw-r--r-- 1 root root  1059 Jan 19  2020 29.2395.jpg
# -rw-r--r-- 1 root root  1074 Jan 19  2020 29.2399.jpg
# -rw-r--r-- 1 root root   918 Jan 19  2020 29.2409.jpg
# -rw-r--r-- 1 root root  1052 Jan 19  2020 29.2418.jpg
# -rw-r--r-- 1 root root   955 Jan 19  2020 29.2447.jpg
# -rw-r--r-- 1 root root  1033 Jan 19  2020 29.2469.jpg
# -rw-r--r-- 1 root root  1125 Jan 19  2020 29.2477.jpg
# -rw-r--r-- 1 root root  1112 Jan 19  2020 29.2488.jpg
# -rw-r--r-- 1 root root  1038 Jan 19  2020 29.2494.jpg
# -rw-r--r-- 1 root root  1033 Jan 19  2020 29.2508.jpg
# -rw-r--r-- 1 root root   975 Jan 19  2020 29.2516.jpg
# -rw-r--r-- 1 root root  1003 Jan 19  2020 29.2518.jpg
# -rw-r--r-- 1 root root   976 Jan 19  2020 29.2525.jpg
# -rw-r--r-- 1 root root  1026 Jan 19  2020 29.2539.jpg
# -rw-r--r-- 1 root root  1063 Jan 19  2020 29.2544.jpg
# -rw-r--r-- 1 root root   989 Jan 19  2020 29.2555.jpg
# -rw-r--r-- 1 root root   982 Jan 18  2020 29.2561.jpg
# -rw-r--r-- 1 root root  1089 Jan 19  2020 29.2566.jpg
# -rw-r--r-- 1 root root  1020 Jan 19  2020 29.2568.jpg
# -rw-r--r-- 1 root root  1047 Jan 19  2020 29.2586.jpg
# -rw-r--r-- 1 root root  1051 Jan 19  2020 29.2588.jpg
# -rw-r--r-- 1 root root  1034 Jan 19  2020 29.2589.jpg
# -rw-r--r-- 1 root root   978 Jan 19  2020 29.2591.jpg
# -rw-r--r-- 1 root root  1030 Jan 19  2020 29.2603.jpg
# -rw-r--r-- 1 root root  1098 Jan 19  2020 29.2615.jpg
# -rw-r--r-- 1 root root  1039 Jan 18  2020 29.2619.jpg
# -rw-r--r-- 1 root root   995 Jan 19  2020 29.2627.jpg
# -rw-r--r-- 1 root root  1042 Jan 19  2020 29.2628.jpg
# -rw-r--r-- 1 root root  1022 Jan 19  2020 29.2645.jpg
# -rw-r--r-- 1 root root  1033 Jan 19  2020 29.2647.jpg
# -rw-r--r-- 1 root root  1129 Jan 19  2020 29.265.jpg
# -rw-r--r-- 1 root root  1091 Jan 19  2020 29.2662.jpg
# -rw-r--r-- 1 root root   994 Jan 19  2020 29.2675.jpg
# -rw-r--r-- 1 root root  1020 Jan 19  2020 29.2676.jpg
# -rw-r--r-- 1 root root  1038 Jan 19  2020 29.2696.jpg
# -rw-r--r-- 1 root root   948 Jan 19  2020 29.2755.jpg
# -rw-r--r-- 1 root root  1031 Jan 19  2020 29.2813.jpg
# -rw-r--r-- 1 root root   957 Jan 19  2020 29.2814.jpg
# -rw-r--r-- 1 root root  1062 Jan 19  2020 29.2857.jpg
# -rw-r--r-- 1 root root   995 Jan 19  2020 29.2858.jpg
# -rw-r--r-- 1 root root  1055 Jan 19  2020 29.2946.jpg
# -rw-r--r-- 1 root root   973 Jan 18  2020 29.2957.jpg
# -rw-r--r-- 1 root root  1036 Jan 19  2020 29.295.jpg
# -rw-r--r-- 1 root root  1125 Jan 19  2020 29.297.jpg
# -rw-r--r-- 1 root root   988 Jan 19  2020 29.3001.jpg
# -rw-r--r-- 1 root root  1054 Jan 19  2020 29.3039.jpg
# -rw-r--r-- 1 root root  1018 Jan 19  2020 29.3049.jpg
# -rw-r--r-- 1 root root  1033 Jan 19  2020 29.3063.jpg
# -rw-r--r-- 1 root root  1062 Jan 19  2020 29.3066.jpg
# -rw-r--r-- 1 root root  1036 Jan 19  2020 29.3076.jpg
# -rw-r--r-- 1 root root   934 Jan 19  2020 29.3077.jpg
# -rw-r--r-- 1 root root  1058 Jan 19  2020 29.3081.jpg
# -rw-r--r-- 1 root root  1018 Jan 18  2020 29.3083.jpg
# -rw-r--r-- 1 root root  1075 Jan 18  2020 29.3084.jpg
# -rw-r--r-- 1 root root  1019 Jan 19  2020 29.3093.jpg
# -rw-r--r-- 1 root root  1046 Jan 18  2020 29.3101.jpg
# -rw-r--r-- 1 root root   955 Jan 19  2020 29.3108.jpg
# -rw-r--r-- 1 root root   938 Jan 19  2020 29.3113.jpg
# -rw-r--r-- 1 root root  1080 Jan 19  2020 29.3142.jpg
# -rw-r--r-- 1 root root  1055 Jan 19  2020 29.3143.jpg
# -rw-r--r-- 1 root root  1136 Jan 19  2020 29.3144.jpg
# -rw-r--r-- 1 root root  1024 Jan 19  2020 29.3152.jpg
# -rw-r--r-- 1 root root   986 Jan 19  2020 29.3156.jpg
# -rw-r--r-- 1 root root  1034 Jan 19  2020 29.3186.jpg
# -rw-r--r-- 1 root root  1034 Jan 19  2020 29.3225.jpg
# -rw-r--r-- 1 root root   978 Jan 19  2020 29.3232.jpg
# -rw-r--r-- 1 root root  1052 Jan 19  2020 29.3245.jpg
# -rw-r--r-- 1 root root  1017 Jan 19  2020 29.3274.jpg
# -rw-r--r-- 1 root root   985 Jan 19  2020 29.3279.jpg
# -rw-r--r-- 1 root root  1048 Jan 19  2020 29.3284.jpg
# -rw-r--r-- 1 root root  1031 Jan 18  2020 29.3299.jpg
# -rw-r--r-- 1 root root  1022 Jan 19  2020 29.3302.jpg
# -rw-r--r-- 1 root root   992 Jan 18  2020 29.3307.jpg
# -rw-r--r-- 1 root root   984 Jan 19  2020 29.3313.jpg
# -rw-r--r-- 1 root root  1107 Jan 19  2020 29.3314.jpg
# -rw-r--r-- 1 root root  1046 Jan 19  2020 29.331.jpg
# -rw-r--r-- 1 root root   972 Jan 19  2020 29.3406.jpg
# -rw-r--r-- 1 root root  1021 Jan 19  2020 29.3414.jpg
# -rw-r--r-- 1 root root  1025 Jan 19  2020 29.3421.jpg
# -rw-r--r-- 1 root root  1018 Jan 19  2020 29.3436.jpg
# -rw-r--r-- 1 root root  1023 Jan 19  2020 29.3459.jpg
# -rw-r--r-- 1 root root  1069 Jan 19  2020 29.3465.jpg
# -rw-r--r-- 1 root root  1090 Jan 18  2020 29.3537.jpg
# -rw-r--r-- 1 root root  1036 Jan 19  2020 29.354.jpg
# -rw-r--r-- 1 root root  1040 Jan 18  2020 29.3571.jpg
# -rw-r--r-- 1 root root  1072 Jan 18  2020 29.3589.jpg
# -rw-r--r-- 1 root root  1008 Jan 19  2020 29.3595.jpg
# -rw-r--r-- 1 root root  1079 Jan 19  2020 29.3599.jpg
# -rw-r--r-- 1 root root   970 Jan 19  2020 29.3613.jpg
# -rw-r--r-- 1 root root   963 Jan 19  2020 29.3647.jpg
# -rw-r--r-- 1 root root  1012 Jan 19  2020 29.3675.jpg
# -rw-r--r-- 1 root root  1032 Jan 19  2020 29.3683.jpg
# -rw-r--r-- 1 root root  1069 Jan 19  2020 29.3692.jpg
# -rw-r--r-- 1 root root  1056 Jan 18  2020 29.3742.jpg
# -rw-r--r-- 1 root root  1047 Jan 19  2020 29.3748.jpg
# -rw-r--r-- 1 root root  1024 Jan 19  2020 29.3758.jpg
# -rw-r--r-- 1 root root  1023 Jan 19  2020 29.3763.jpg
# -rw-r--r-- 1 root root  1025 Jan 19  2020 29.3768.jpg
# -rw-r--r-- 1 root root  1028 Jan 19  2020 29.3772.jpg
# -rw-r--r-- 1 root root  1063 Jan 19  2020 29.3775.jpg
# -rw-r--r-- 1 root root  1001 Jan 19  2020 29.3778.jpg
# -rw-r--r-- 1 root root   987 Jan 19  2020 29.3784.jpg
# -rw-r--r-- 1 root root  1062 Jan 19  2020 29.3802.jpg
# -rw-r--r-- 1 root root   971 Jan 19  2020 29.3809.jpg
# -rw-r--r-- 1 root root  1028 Jan 19  2020 29.3813.jpg
# -rw-r--r-- 1 root root  1068 Jan 19  2020 29.3835.jpg
# -rw-r--r-- 1 root root   992 Jan 19  2020 29.3884.jpg
# -rw-r--r-- 1 root root   940 Jan 19  2020 29.3899.jpg
# -rw-r--r-- 1 root root   967 Jan 19  2020 29.3918.jpg
# -rw-r--r-- 1 root root   989 Jan 19  2020 29.3921.jpg
# -rw-r--r-- 1 root root  1015 Jan 19  2020 29.3941.jpg
# -rw-r--r-- 1 root root   924 Jan 19  2020 29.3949.jpg
# -rw-r--r-- 1 root root   937 Jan 19  2020 29.3963.jpg
# -rw-r--r-- 1 root root   993 Jan 19  2020 29.3966.jpg
# -rw-r--r-- 1 root root   992 Jan 19  2020 29.3985.jpg
# -rw-r--r-- 1 root root  1019 Jan 19  2020 29.398.jpg
# -rw-r--r-- 1 root root  1019 Jan 19  2020 29.4001.jpg
# -rw-r--r-- 1 root root  1018 Jan 19  2020 29.4021.jpg
# -rw-r--r-- 1 root root  1046 Jan 19  2020 29.4031.jpg
# -rw-r--r-- 1 root root  1025 Jan 19  2020 29.4055.jpg
# -rw-r--r-- 1 root root   941 Jan 19  2020 29.4064.jpg
# -rw-r--r-- 1 root root   993 Jan 19  2020 29.4077.jpg
# -rw-r--r-- 1 root root  1006 Jan 19  2020 29.4082.jpg
# -rw-r--r-- 1 root root  1060 Jan 19  2020 29.4091.jpg
# -rw-r--r-- 1 root root   969 Jan 19  2020 29.409.jpg
# -rw-r--r-- 1 root root  1046 Jan 19  2020 29.4105.jpg
# -rw-r--r-- 1 root root  1035 Jan 19  2020 29.4138.jpg
# -rw-r--r-- 1 root root   994 Jan 19  2020 29.4155.jpg
# -rw-r--r-- 1 root root  1048 Jan 19  2020 29.4156.jpg
# -rw-r--r-- 1 root root  1100 Jan 18  2020 29.4166.jpg
# -rw-r--r-- 1 root root  1002 Jan 19  2020 29.4178.jpg
# -rw-r--r-- 1 root root  1108 Jan 19  2020 29.4246.jpg
# -rw-r--r-- 1 root root  1100 Jan 18  2020 29.4253.jpg
# -rw-r--r-- 1 root root   983 Jan 19  2020 29.4265.jpg
# -rw-r--r-- 1 root root   999 Jan 19  2020 29.426.jpg
# -rw-r--r-- 1 root root  1056 Jan 19  2020 29.4292.jpg
# -rw-r--r-- 1 root root  1068 Jan 19  2020 29.4293.jpg
# -rw-r--r-- 1 root root  1059 Jan 19  2020 29.4298.jpg
# -rw-r--r-- 1 root root  1035 Jan 19  2020 29.429.jpg
# -rw-r--r-- 1 root root  1135 Jan 19  2020 29.4343.jpg
# -rw-r--r-- 1 root root  1023 Jan 19  2020 29.435.jpg
# -rw-r--r-- 1 root root  1040 Jan 19  2020 29.4374.jpg
# -rw-r--r-- 1 root root  1035 Jan 18  2020 29.4375.jpg
# -rw-r--r-- 1 root root  1085 Jan 19  2020 29.4382.jpg
# -rw-r--r-- 1 root root  1008 Jan 19  2020 29.4392.jpg
# -rw-r--r-- 1 root root  1050 Jan 19  2020 29.4427.jpg
# -rw-r--r-- 1 root root  1034 Jan 19  2020 29.4454.jpg
# -rw-r--r-- 1 root root  1060 Jan 19  2020 29.4456.jpg
# -rw-r--r-- 1 root root  1034 Jan 19  2020 29.4465.jpg
# -rw-r--r-- 1 root root  1026 Jan 19  2020 29.4469.jpg
# -rw-r--r-- 1 root root  1039 Jan 19  2020 29.4471.jpg
# -rw-r--r-- 1 root root   964 Jan 19  2020 29.4476.jpg
# -rw-r--r-- 1 root root  1071 Jan 19  2020 29.4478.jpg
# -rw-r--r-- 1 root root  1081 Jan 19  2020 29.4504.jpg
# -rw-r--r-- 1 root root  1057 Jan 18  2020 29.4513.jpg
# -rw-r--r-- 1 root root  1023 Jan 19  2020 29.4524.jpg
# -rw-r--r-- 1 root root   975 Jan 19  2020 29.4526.jpg
# -rw-r--r-- 1 root root   894 Jan 19  2020 29.4531.jpg
# -rw-r--r-- 1 root root  1078 Jan 19  2020 29.4567.jpg
# -rw-r--r-- 1 root root  1065 Jan 18  2020 29.4582.jpg
# -rw-r--r-- 1 root root  1043 Jan 19  2020 29.4592.jpg
# -rw-r--r-- 1 root root  1014 Jan 19  2020 29.4611.jpg
# -rw-r--r-- 1 root root  1041 Jan 18  2020 29.4617.jpg
# -rw-r--r-- 1 root root  1093 Jan 19  2020 29.4665.jpg
# -rw-r--r-- 1 root root  1023 Jan 19  2020 29.4668.jpg
# -rw-r--r-- 1 root root  1117 Jan 19  2020 29.4686.jpg
# -rw-r--r-- 1 root root   969 Jan 19  2020 29.4688.jpg
# -rw-r--r-- 1 root root  1017 Jan 19  2020 29.4692.jpg
# -rw-r--r-- 1 root root  1054 Jan 19  2020 29.4715.jpg
# -rw-r--r-- 1 root root  1025 Jan 18  2020 29.4729.jpg
# -rw-r--r-- 1 root root  1036 Jan 19  2020 29.477.jpg
# -rw-r--r-- 1 root root  1015 Jan 19  2020 29.4782.jpg
# -rw-r--r-- 1 root root  1055 Jan 19  2020 29.4796.jpg
# -rw-r--r-- 1 root root  1076 Jan 19  2020 29.4836.jpg
# -rw-r--r-- 1 root root  1019 Jan 19  2020 29.4847.jpg
# -rw-r--r-- 1 root root   997 Jan 19  2020 29.4855.jpg
# -rw-r--r-- 1 root root  1026 Jan 19  2020 29.4868.jpg
# -rw-r--r-- 1 root root   979 Jan 19  2020 29.4874.jpg
# -rw-r--r-- 1 root root   971 Jan 19  2020 29.4875.jpg
# -rw-r--r-- 1 root root  1001 Jan 19  2020 29.489.jpg
# -rw-r--r-- 1 root root   977 Jan 19  2020 29.4914.jpg
# -rw-r--r-- 1 root root  1010 Jan 19  2020 29.4934.jpg
# -rw-r--r-- 1 root root  1076 Jan 19  2020 29.4944.jpg
# -rw-r--r-- 1 root root  1009 Jan 19  2020 29.4949.jpg
# -rw-r--r-- 1 root root   957 Jan 19  2020 29.4968.jpg
# -rw-r--r-- 1 root root  1028 Jan 19  2020 29.497.jpg
# -rw-r--r-- 1 root root  1033 Jan 18  2020 29.4986.jpg
# -rw-r--r-- 1 root root  1040 Jan 19  2020 29.4997.jpg
# -rw-r--r-- 1 root root  1044 Jan 19  2020 29.5021.jpg
# -rw-r--r-- 1 root root  1014 Jan 18  2020 29.5026.jpg
# -rw-r--r-- 1 root root  1054 Jan 19  2020 29.505.jpg
# -rw-r--r-- 1 root root  1033 Jan 19  2020 29.5102.jpg
# -rw-r--r-- 1 root root   950 Jan 19  2020 29.5112.jpg
# -rw-r--r-- 1 root root   996 Jan 19  2020 29.5117.jpg
# -rw-r--r-- 1 root root  1003 Jan 19  2020 29.5123.jpg
# -rw-r--r-- 1 root root  1044 Jan 19  2020 29.5157.jpg
# -rw-r--r-- 1 root root  1030 Jan 18  2020 29.5163.jpg
# -rw-r--r-- 1 root root  1038 Jan 19  2020 29.5165.jpg
# -rw-r--r-- 1 root root  1019 Jan 18  2020 29.5169.jpg
# -rw-r--r-- 1 root root  1047 Jan 19  2020 29.5185.jpg
# -rw-r--r-- 1 root root  1076 Jan 19  2020 29.5192.jpg
# -rw-r--r-- 1 root root  1060 Jan 19  2020 29.5208.jpg
# -rw-r--r-- 1 root root  1038 Jan 19  2020 29.5226.jpg
# -rw-r--r-- 1 root root  1074 Jan 19  2020 29.5234.jpg
# -rw-r--r-- 1 root root  1082 Jan 19  2020 29.5252.jpg
# -rw-r--r-- 1 root root  1035 Jan 19  2020 29.5271.jpg
# -rw-r--r-- 1 root root  1026 Jan 19  2020 29.5286.jpg
# -rw-r--r-- 1 root root  1031 Jan 19  2020 29.5289.jpg
# -rw-r--r-- 1 root root  1036 Jan 19  2020 29.5291.jpg
# -rw-r--r-- 1 root root  1094 Jan 18  2020 29.5302.jpg
# -rw-r--r-- 1 root root  1076 Jan 19  2020 29.5312.jpg
# -rw-r--r-- 1 root root  1030 Jan 19  2020 29.5339.jpg
# -rw-r--r-- 1 root root  1037 Jan 19  2020 29.533.jpg
# -rw-r--r-- 1 root root   959 Jan 19  2020 29.5343.jpg
# -rw-r--r-- 1 root root   998 Jan 19  2020 29.5351.jpg
# -rw-r--r-- 1 root root   986 Jan 19  2020 29.5364.jpg
# -rw-r--r-- 1 root root   945 Jan 19  2020 29.5367.jpg
# -rw-r--r-- 1 root root  1028 Jan 19  2020 29.5394.jpg
# -rw-r--r-- 1 root root  1040 Jan 19  2020 29.5422.jpg
# -rw-r--r-- 1 root root   990 Jan 19  2020 29.5448.jpg
# -rw-r--r-- 1 root root   977 Jan 19  2020 29.5451.jpg
# -rw-r--r-- 1 root root   974 Jan 19  2020 29.5465.jpg
# -rw-r--r-- 1 root root   981 Jan 19  2020 29.5477.jpg
# -rw-r--r-- 1 root root  1091 Jan 18  2020 29.547.jpg
# -rw-r--r-- 1 root root  1039 Jan 18  2020 29.548.jpg
# -rw-r--r-- 1 root root  1058 Jan 19  2020 29.581.jpg
# -rw-r--r-- 1 root root  1039 Jan 19  2020 29.587.jpg
# -rw-r--r-- 1 root root  1029 Jan 19  2020 29.603.jpg
# -rw-r--r-- 1 root root   997 Jan 19  2020 29.607.jpg
# -rw-r--r-- 1 root root  1006 Jan 19  2020 29.613.jpg
# -rw-r--r-- 1 root root  1008 Jan 19  2020 29.619.jpg
# -rw-r--r-- 1 root root  1011 Jan 19  2020 29.631.jpg
# -rw-r--r-- 1 root root  1024 Jan 19  2020 29.64.jpg
# -rw-r--r-- 1 root root  1143 Jan 19  2020 29.653.jpg
# -rw-r--r-- 1 root root  1086 Jan 19  2020 29.665.jpg
# -rw-r--r-- 1 root root  1031 Jan 19  2020 29.669.jpg
# -rw-r--r-- 1 root root  1018 Jan 19  2020 29.681.jpg
# -rw-r--r-- 1 root root  1056 Jan 19  2020 29.684.jpg
# -rw-r--r-- 1 root root  1023 Jan 18  2020 29.708.jpg
# -rw-r--r-- 1 root root  1047 Jan 19  2020 29.727.jpg
# -rw-r--r-- 1 root root  1058 Jan 19  2020 29.761.jpg
# -rw-r--r-- 1 root root  1062 Jan 18  2020 29.79.jpg
# -rw-r--r-- 1 root root  1114 Jan 19  2020 29.808.jpg
# -rw-r--r-- 1 root root  1037 Jan 19  2020 29.828.jpg
# -rw-r--r-- 1 root root  1068 Jan 19  2020 29.866.jpg
# -rw-r--r-- 1 root root  1049 Jan 19  2020 29.898.jpg
# -rw-r--r-- 1 root root   988 Jan 19  2020 29.907.jpg
# -rw-r--r-- 1 root root  1036 Jan 19  2020 29.925.jpg
# -rw-r--r-- 1 root root  1006 Jan 19  2020 29.944.jpg
# -rw-r--r-- 1 root root   987 Jan 19  2020 29.971.jpg

# %%
# 압축해제된 데이터 경로를 찾아 복사해서 붙여넣어주세요
src = './data_3000/'

# 이미지 읽기 및 출력
def img_read_plot(src,file):
    img = cv.imread(src+file,cv.COLOR_BGR2GRAY)
    plt.imshow(img)
    plt.xticks([]) # x축 눈금
    plt.yticks([]) # y축 눈금
    plt.show()
    return img

#이미지 읽기
def img_read(src,file):
    img = cv.imread(src+file,cv.COLOR_BGR2GRAY)
    return img

#src 경로에 있는 파일 명을 저장합니다.
files = os.listdir(src)

# 경로와 파일명을 입력으로 넣어 확인하고
# 데이터를 255로 나눠서 0~1사이로 정규화 하여 X 리스트에 넣습니다.

X,Y = [],[]
for file in files:
  X.append(img_read(src,file)/255.)
  Y.append(float(file[:-4]))


# Train set, Test set으로 나누기
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, random_state=1,shuffle=True)
x_train = np.array(x_train)
x_test = np.array(x_test)


 # (image,image)이미지를 크기의 (image*image,)크기의 벡터로 만듭니다
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:]))).astype('float32')
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:]))).astype('float32')

print("Datasets_train_shape:{}  Datasets_test_shape:{}".format(np.shape(x_train),np.shape(x_test)))
# Out:
# Datasets_train_shape:(2400, 3136)  Datasets_test_shape:(600, 3136)

# %% [markdown]
# VAE 모델만들기

# %%
# network parameters
input_shape = np.shape(x_train[0])[0]
original_dim= input_shape
intermediate_dim = 512
latent_dim = 2

# %%
def encoder():
  # 인코더의 입력층을 생성합니다.
  inputs = Input(shape=(input_shape,), name='input_shape')

  # 인코더의 hidden층을 생성합니다. 500개의 유닛을 사용했습니다.
  encoder_hidden = layers.Dense(intermediate_dim, activation='relu', name='encoder_hidden1')(inputs)

  # 평균(mean)과 표준편차(sigma)층을 정의합니다.
  # 이때 sigma 대신 log variance를 사용합니다. 이는 신경망의 출력은 음수를 가질 수 있지만 sigma는 항상 양수여야 하기 때문입니다.
  # 각각 2개의 유닛을 사용했습니다.
  z_mean = layers.Dense(latent_dim, name='z_mean')(encoder_hidden)
  z_log_var = layers.Dense(latent_dim, name='z_log_var')(encoder_hidden)

  # 평균과 표준편차를 래핑하여 Z_sampling층을 만듭니다.

  # Z 샘플링 함수 생성
  def sampling(args):
      z_mean, z_log_var = args
      batch = shape(z_mean)[0]
      dim = shape(z_mean)[1]

      # by default, random_normal has mean = 0 and std = 1.0
      # Reparameterization Trick사용을 위해 Gussian(=normal)분포에서 랜덤변수(sample) ε추출
      epsilon = tf.compat.v2.random.normal(shape=(batch, dim))
      return z_mean + tf.math.exp(0.5 * z_log_var) * epsilon

  #  layers.Lambda API 래핑에 사용할 함수와, 유닛수(n,)를 지정합니다.
  z_sampling = layers.Lambda(sampling, (latent_dim,), name='z_sample')([z_mean, z_log_var])

  # 하나의 입력과 다중충력을 포함하는 encoder 모델을 만듭니다.
  return Model(inputs,[z_mean,z_log_var,z_sampling], name='encoder')

encoder = encoder()

# 인코더 네트워크를 확인합니다.
encoder.summary()

from tensorflow.keras.utils import plot_model
plot_model(encoder, to_file='vae_mlp_encoder.png', show_shapes=True)
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_shape (InputLayer)       [(None, 3136)]       0           []
#
#  encoder_hidden1 (Dense)        (None, 512)          1606144     ['input_shape[0][0]']
#
#  z_mean (Dense)                 (None, 2)            1026        ['encoder_hidden1[0][0]']
#
#  z_log_var (Dense)              (None, 2)            1026        ['encoder_hidden1[0][0]']
#
#  z_sample (Lambda)              (None, 2)            0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 1,608,196
# Trainable params: 1,608,196
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Decoder

# %%
def decoder():

  # 디코더의 입력층을 생성합니다. (Decoder의 입력은 latent입니다)
  input_z = Input(shape=(latent_dim,), name='input_z')

  # 디코더의 hidden층을 생성합니다. 인코더와 동일하게 500개의 유닛을 사용했습니다.
  decoder_hidden = layers.Dense(intermediate_dim, activation='relu', name='decoder_hidden')(input_z)

  # 디코더의 출력층은 인코더 입력벡터 수만큼 유닛을 사용합니다.
  outputs = layers.Dense(original_dim, activation='sigmoid',name='output')(decoder_hidden)

  return Model(input_z, outputs, name='decoder')

decoder = decoder()

# 디코더의 네트워크 확인.
decoder.summary()
plot_model(decoder, to_file='vae_mlp_decoder.png', show_shapes=True)
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_z (InputLayer)        [(None, 2)]               0
#
#  decoder_hidden (Dense)      (None, 512)               1536
#
#  output (Dense)              (None, 3136)              1608768
#
# =================================================================
# Total params: 1,610,304
# Trainable params: 1,610,304
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# modelfit

# %%
#Hyperparameters
num_epochs = 100
batch_size = 2
learning_rate = 1e-3

# %%
# 모델 학습 loss, optimizer 정의
adam = tf.keras.optimizers.Adam(learning_rate=learning_rate)
model.compile(optimizer= adam, loss='mse')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-45d6551673ce> in <cell line: 13>()
#      11     kl_loss = 0.5 * tf.reduce_sum(tf.square(z_mean)+ tf.exp(z_log_var)- z_log_var -1, 1)
#      12     return tf.reduce_mean(reconstruction_loss + kl_loss) #ELBO(=VAE_loss)
# ---> 13 model.compile(optimizer= adam, loss='mse')
#
# NameError: name 'model' is not defined

# %%
# 모델 학습
hist = model.fit(x_train, x_train, epochs=num_epochs, batch_size=batch_size, shuffle=True, verbose=1)

# 학습된 VAE 모델 저장
model.save_weights('ae_bracket.h5')

# %%
recon_x_test = model.predict(x_test)                #

n = 10  # how many digits we will display
plt.figure(figsize=(15, 4))
for i in range(10):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(56,56), vmin=0, vmax=1, cmap="gray")
    plt.title("Input"+str(i))
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    #plt.colorbar()

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(recon_x_test[i].reshape(56, 56),vmin=0, vmax=1, cmap="gray")
    plt.title("Recon"+str(i))
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    #plt.colorbar()
plt.show()
