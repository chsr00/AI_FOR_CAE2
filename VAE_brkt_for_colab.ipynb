# %% [markdown]
# <a href="https://colab.research.google.com/github/chsr00/AI_FOR_CAE2/blob/main/VAE_brkt_for_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
# Out:
# Colab only includes TensorFlow 2.x; %tensorflow_version has no effect.

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2 as cv
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow import shape,math
from tensorflow.keras import Input,layers,Model
from tensorflow.keras.losses import mse,binary_crossentropy
from tensorflow.keras.utils import plot_model

print(tf.__version__)
# Out:
# 2.12.0

# %% [markdown]
# 데이터 불러오기

# %%
#from google.colab import files

#uploaded = files.upload()

## 코드가 돌아가면 파일선택 버튼을 눌러서 upload할 파일 선택
#for fn in uploaded.keys():
#  print('User uploaded file "{name}" with length {length} bytes'.format(
#      name=fn, length=len(uploaded[fn])))

# !git clone https://github.com/chsr00/AI_FOR_CAE2.git
# Out:
# Cloning into 'AI_FOR_CAE2'...
# remote: Enumerating objects: 36, done.
# remote: Counting objects: 100% (36/36), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 36 (delta 14), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (36/36), 3.09 MiB | 6.98 MiB/s, done.
# Resolving deltas: 100% (14/14), done.

# %%
! mkdir data_3000
! unzip ./AI_FOR_CAE2/data_3000.zip
! pwd
#! ls -al
#! cd /content/AI_FOR_CAE2
#! ls -al
! mv *.jpg ./data_3000/
#!ls -al ./data_3000
# Out:
# Archive:  ./AI_FOR_CAE2/data_3000.zip
#   inflating: 22.5651.jpg
#   inflating: 23.119.jpg
#   inflating: 23.149.jpg
#   inflating: 23.2255.jpg
#   inflating: 23.2919.jpg
#   inflating: 23.3077.jpg
#   inflating: 23.3701.jpg
#   inflating: 23.388.jpg
#   inflating: 23.4496.jpg
#   inflating: 23.4706.jpg
#   inflating: 23.4709.jpg
#   inflating: 23.4904.jpg
#   inflating: 23.5079.jpg
#   inflating: 23.5414.jpg
#   inflating: 23.5748.jpg
#   inflating: 23.5762.jpg
#   inflating: 23.587.jpg
#   inflating: 23.5886.jpg
#   inflating: 23.5889.jpg
#   inflating: 23.6748.jpg
#   inflating: 23.6771.jpg
#   inflating: 23.6777.jpg
#   inflating: 23.689.jpg
#   inflating: 23.7302.jpg
#   inflating: 23.7464.jpg
#   inflating: 23.7518.jpg
#   inflating: 23.7574.jpg
#   inflating: 23.7633.jpg
#   inflating: 23.7762.jpg
#   inflating: 23.7876.jpg
#   inflating: 23.7911.jpg
#   inflating: 23.7928.jpg
#   inflating: 23.8164.jpg
#   inflating: 23.8167.jpg
#   inflating: 23.8217.jpg
#   inflating: 23.8435.jpg
#   inflating: 23.8441.jpg
#   inflating: 23.8576.jpg
#   inflating: 23.8578.jpg
#   inflating: 23.8668.jpg
#   inflating: 23.879.jpg
#   inflating: 23.8812.jpg
#   inflating: 23.8939.jpg
#   inflating: 23.8971.jpg
#   inflating: 23.9093.jpg
#   inflating: 23.9157.jpg
#   inflating: 23.9208.jpg
#   inflating: 23.9293.jpg
#   inflating: 23.9357.jpg
#   inflating: 23.9481.jpg
#   inflating: 23.9548.jpg
#   inflating: 23.9595.jpg
#   inflating: 23.9676.jpg
#   inflating: 23.9721.jpg
#   inflating: 23.9768.jpg
#   inflating: 23.9842.jpg
#   inflating: 23.9973.jpg
#   inflating: 24.0008.jpg
#   inflating: 24.018.jpg
#   inflating: 24.045.jpg
#   inflating: 24.0505.jpg
#   inflating: 24.0527.jpg
#   inflating: 24.0533.jpg
#   inflating: 24.0626.jpg
#   inflating: 24.0635.jpg
#   inflating: 24.0705.jpg
#   inflating: 24.0963.jpg
#   inflating: 24.1021.jpg
#   inflating: 24.1189.jpg
#   inflating: 24.1204.jpg
#   inflating: 24.1353.jpg
#   inflating: 24.1376.jpg
#   inflating: 24.1506.jpg
#   inflating: 24.151.jpg
#   inflating: 24.152.jpg
#   inflating: 24.1598.jpg
#   inflating: 24.1666.jpg
#   inflating: 24.1718.jpg
#   inflating: 24.177.jpg
#   inflating: 24.1802.jpg
#   inflating: 24.1939.jpg
#   inflating: 24.201.jpg
#   inflating: 24.214.jpg
#   inflating: 24.2167.jpg
#   inflating: 24.2171.jpg
#   inflating: 24.2415.jpg
#   inflating: 24.2437.jpg
#   inflating: 24.2471.jpg
#   inflating: 24.2548.jpg
#   inflating: 24.2597.jpg
#   inflating: 24.264.jpg
#   inflating: 24.2759.jpg
#   inflating: 24.2818.jpg
#   inflating: 24.282.jpg
#   inflating: 24.2859.jpg
#   inflating: 24.2929.jpg
#   inflating: 24.2933.jpg
#   inflating: 24.3183.jpg
#   inflating: 24.3305.jpg
#   inflating: 24.3395.jpg
#   inflating: 24.3414.jpg
#   inflating: 24.3429.jpg
#   inflating: 24.3441.jpg
#   inflating: 24.3605.jpg
#   inflating: 24.3626.jpg
#   inflating: 24.3752.jpg
#   inflating: 24.3767.jpg
#   inflating: 24.3793.jpg
#   inflating: 24.3829.jpg
#   inflating: 24.3832.jpg
#   inflating: 24.3869.jpg
#   inflating: 24.3877.jpg
#   inflating: 24.3881.jpg
#   inflating: 24.4018.jpg
#   inflating: 24.402.jpg
#   inflating: 24.4062.jpg
#   inflating: 24.4083.jpg
#   inflating: 24.4116.jpg
#   inflating: 24.4123.jpg
#   inflating: 24.413.jpg
#   inflating: 24.414.jpg
#   inflating: 24.4151.jpg
#   inflating: 24.4204.jpg
#   inflating: 24.4253.jpg
#   inflating: 24.4334.jpg
#   inflating: 24.4342.jpg
#   inflating: 24.4432.jpg
#   inflating: 24.4472.jpg
#   inflating: 24.4502.jpg
#   inflating: 24.4505.jpg
#   inflating: 24.4523.jpg
#   inflating: 24.4552.jpg
#   inflating: 24.457.jpg
#   inflating: 24.4673.jpg
#   inflating: 24.4703.jpg
#   inflating: 24.471.jpg
#   inflating: 24.4716.jpg
#   inflating: 24.4964.jpg
#   inflating: 24.5039.jpg
#   inflating: 24.5089.jpg
#   inflating: 24.5274.jpg
#   inflating: 24.5303.jpg
#   inflating: 24.5308.jpg
#   inflating: 24.5315.jpg
#   inflating: 24.5365.jpg
#   inflating: 24.5367.jpg
#   inflating: 24.5445.jpg
#   inflating: 24.5454.jpg
#   inflating: 24.5465.jpg
#   inflating: 24.5529.jpg
#   inflating: 24.5536.jpg
#   inflating: 24.5545.jpg
#   inflating: 24.5552.jpg
#   inflating: 24.5557.jpg
#   inflating: 24.5612.jpg
#   inflating: 24.5715.jpg
#   inflating: 24.5726.jpg
#   inflating: 24.5737.jpg
#   inflating: 24.577.jpg
#   inflating: 24.5866.jpg
#   inflating: 24.5956.jpg
#   inflating: 24.5975.jpg
#   inflating: 24.6028.jpg
#   inflating: 24.609.jpg
#   inflating: 24.6158.jpg
#   inflating: 24.62.jpg
#   inflating: 24.6204.jpg
#   inflating: 24.6283.jpg
#   inflating: 24.6381.jpg
#   inflating: 24.6418.jpg
#   inflating: 24.643.jpg
#   inflating: 24.6499.jpg
#   inflating: 24.6529.jpg
#   inflating: 24.654.jpg
#   inflating: 24.6577.jpg
#   inflating: 24.6578.jpg
#   inflating: 24.6609.jpg
#   inflating: 24.6613.jpg
#   inflating: 24.6647.jpg
#   inflating: 24.6654.jpg
#   inflating: 24.6697.jpg
#   inflating: 24.6706.jpg
#   inflating: 24.6745.jpg
#   inflating: 24.6768.jpg
#   inflating: 24.6794.jpg
#   inflating: 24.6809.jpg
#   inflating: 24.6814.jpg
#   inflating: 24.6887.jpg
#   inflating: 24.6893.jpg
#   inflating: 24.6996.jpg
#   inflating: 24.7018.jpg
#   inflating: 24.7052.jpg
#   inflating: 24.7133.jpg
#   inflating: 24.7176.jpg
#   inflating: 24.7211.jpg
#   inflating: 24.7232.jpg
#   inflating: 24.7273.jpg
#   inflating: 24.7313.jpg
#   inflating: 24.735.jpg
#   inflating: 24.7365.jpg
#   inflating: 24.7378.jpg
#   inflating: 24.746.jpg
#   inflating: 24.7471.jpg
#   inflating: 24.7478.jpg
#   inflating: 24.7513.jpg
#   inflating: 24.7514.jpg
#   inflating: 24.7576.jpg
#   inflating: 24.7703.jpg
#   inflating: 24.771.jpg
#   inflating: 24.7816.jpg
#   inflating: 24.7864.jpg
#   inflating: 24.7891.jpg
#   inflating: 24.7919.jpg
#   inflating: 24.7924.jpg
#   inflating: 24.7945.jpg
#   inflating: 24.8019.jpg
#   inflating: 24.8027.jpg
#   inflating: 24.8154.jpg
#   inflating: 24.8181.jpg
#   inflating: 24.8186.jpg
#   inflating: 24.8242.jpg
#   inflating: 24.8254.jpg
#   inflating: 24.8381.jpg
#   inflating: 24.8396.jpg
#   inflating: 24.8437.jpg
#   inflating: 24.8441.jpg
#   inflating: 24.8456.jpg
#   inflating: 24.8551.jpg
#   inflating: 24.8555.jpg
#   inflating: 24.8614.jpg
#   inflating: 24.8641.jpg
#   inflating: 24.8682.jpg
#   inflating: 24.8707.jpg
#   inflating: 24.8709.jpg
#   inflating: 24.8718.jpg
#   inflating: 24.8729.jpg
#   inflating: 24.874.jpg
#   inflating: 24.8779.jpg
#   inflating: 24.8921.jpg
#   inflating: 24.8942.jpg
#   inflating: 24.8963.jpg
#   inflating: 24.8987.jpg
#   inflating: 24.9002.jpg
#   inflating: 24.901.jpg
#   inflating: 24.9051.jpg
#   inflating: 24.9177.jpg
#   inflating: 24.9202.jpg
#   inflating: 24.9213.jpg
#   inflating: 24.9227.jpg
#   inflating: 24.9287.jpg
#   inflating: 24.9295.jpg
#   inflating: 24.9403.jpg
#   inflating: 24.9411.jpg
#   inflating: 24.9433.jpg
#   inflating: 24.9434.jpg
#   inflating: 24.9437.jpg
#   inflating: 24.9438.jpg
#   inflating: 24.9456.jpg
#   inflating: 24.9482.jpg
#   inflating: 24.9488.jpg
#   inflating: 24.9509.jpg
#   inflating: 24.9558.jpg
#   inflating: 24.9577.jpg
#   inflating: 24.9615.jpg
#   inflating: 24.9632.jpg
#   inflating: 24.9669.jpg
#   inflating: 24.9828.jpg
#   inflating: 24.9831.jpg
#   inflating: 24.9838.jpg
#   inflating: 24.9854.jpg
#   inflating: 24.9892.jpg
#   inflating: 24.99.jpg
#   inflating: 24.9929.jpg
#   inflating: 24.9949.jpg
#   inflating: 24.9969.jpg
#   inflating: 24.9972.jpg
#   inflating: 24.9978.jpg
#   inflating: 25.0021.jpg
#   inflating: 25.0069.jpg
#   inflating: 25.0134.jpg
#   inflating: 25.029.jpg
#   inflating: 25.03.jpg
#   inflating: 25.036.jpg
#   inflating: 25.0363.jpg
#   inflating: 25.0398.jpg
#   inflating: 25.0464.jpg
#   inflating: 25.0498.jpg
#   inflating: 25.0564.jpg
#   inflating: 25.0589.jpg
#   inflating: 25.0596.jpg
#   inflating: 25.0724.jpg
#   inflating: 25.0729.jpg
#   inflating: 25.073.jpg
#   inflating: 25.0732.jpg
#   inflating: 25.0742.jpg
#   inflating: 25.0755.jpg
#   inflating: 25.0762.jpg
#   inflating: 25.0798.jpg
#   inflating: 25.0842.jpg
#   inflating: 25.0861.jpg
#   inflating: 25.0875.jpg
#   inflating: 25.0884.jpg
#   inflating: 25.0887.jpg
#   inflating: 25.0967.jpg
#   inflating: 25.098.jpg
#   inflating: 25.0997.jpg
#   inflating: 25.1008.jpg
#   inflating: 25.1017.jpg
#   inflating: 25.1059.jpg
#   inflating: 25.107.jpg
#   inflating: 25.1106.jpg
#   inflating: 25.1109.jpg
#   inflating: 25.1119.jpg
#   inflating: 25.1134.jpg
#   inflating: 25.1151.jpg
#   inflating: 25.1183.jpg
#   inflating: 25.1216.jpg
#   inflating: 25.122.jpg
#   inflating: 25.1231.jpg
#   inflating: 25.1251.jpg
#   inflating: 25.1318.jpg
#   inflating: 25.1343.jpg
#   inflating: 25.1364.jpg
#   inflating: 25.1416.jpg
#   inflating: 25.146.jpg
#   inflating: 25.1469.jpg
#   inflating: 25.151.jpg
#   inflating: 25.1534.jpg
#   inflating: 25.1538.jpg
#   inflating: 25.1578.jpg
#   inflating: 25.1615.jpg
#   inflating: 25.1618.jpg
#   inflating: 25.1692.jpg
#   inflating: 25.1722.jpg
#   inflating: 25.1762.jpg
#   inflating: 25.178.jpg
#   inflating: 25.1804.jpg
#   inflating: 25.1841.jpg
#   inflating: 25.1874.jpg
#   inflating: 25.1917.jpg
#   inflating: 25.1938.jpg
#   inflating: 25.1998.jpg
#   inflating: 25.2003.jpg
#   inflating: 25.2021.jpg
#   inflating: 25.2026.jpg
#   inflating: 25.2032.jpg
#   inflating: 25.2084.jpg
#   inflating: 25.2128.jpg
#   inflating: 25.2146.jpg
#   inflating: 25.2154.jpg
#   inflating: 25.2206.jpg
#   inflating: 25.2225.jpg
#   inflating: 25.2251.jpg
#   inflating: 25.2262.jpg
#   inflating: 25.2284.jpg
#   inflating: 25.2291.jpg
#   inflating: 25.2315.jpg
#   inflating: 25.2316.jpg
#   inflating: 25.232.jpg
#   inflating: 25.2332.jpg
#   inflating: 25.2372.jpg
#   inflating: 25.2373.jpg
#   inflating: 25.2395.jpg
#   inflating: 25.2405.jpg
#   inflating: 25.242.jpg
#   inflating: 25.2426.jpg
#   inflating: 25.2449.jpg
#   inflating: 25.2477.jpg
#   inflating: 25.2478.jpg
#   inflating: 25.2524.jpg
#   inflating: 25.2542.jpg
#   inflating: 25.2565.jpg
#   inflating: 25.2574.jpg
#   inflating: 25.2576.jpg
#   inflating: 25.2612.jpg
#   inflating: 25.264.jpg
#   inflating: 25.268.jpg
#   inflating: 25.2736.jpg
#   inflating: 25.2815.jpg
#   inflating: 25.2877.jpg
#   inflating: 25.2887.jpg
#   inflating: 25.2901.jpg
#   inflating: 25.293.jpg
#   inflating: 25.2941.jpg
#   inflating: 25.2942.jpg
#   inflating: 25.2954.jpg
#   inflating: 25.2973.jpg
#   inflating: 25.3023.jpg
#   inflating: 25.3047.jpg
#   inflating: 25.3065.jpg
#   inflating: 25.3067.jpg
#   inflating: 25.3072.jpg
#   inflating: 25.3215.jpg
#   inflating: 25.3233.jpg
#   inflating: 25.3234.jpg
#   inflating: 25.3241.jpg
#   inflating: 25.3311.jpg
#   inflating: 25.3313.jpg
#   inflating: 25.3328.jpg
#   inflating: 25.3332.jpg
#   inflating: 25.3338.jpg
#   inflating: 25.3341.jpg
#   inflating: 25.3349.jpg
#   inflating: 25.3352.jpg
#   inflating: 25.3357.jpg
#   inflating: 25.3371.jpg
#   inflating: 25.3403.jpg
#   inflating: 25.3424.jpg
#   inflating: 25.3433.jpg
#   inflating: 25.3454.jpg
#   inflating: 25.3462.jpg
#   inflating: 25.3489.jpg
#   inflating: 25.35.jpg
#   inflating: 25.3515.jpg
#   inflating: 25.3525.jpg
#   inflating: 25.3538.jpg
#   inflating: 25.3539.jpg
#   inflating: 25.3556.jpg
#   inflating: 25.3557.jpg
#   inflating: 25.3567.jpg
#   inflating: 25.3572.jpg
#   inflating: 25.3576.jpg
#   inflating: 25.3594.jpg
#   inflating: 25.3602.jpg
#   inflating: 25.3615.jpg
#   inflating: 25.3651.jpg
#   inflating: 25.3666.jpg
#   inflating: 25.3673.jpg
#   inflating: 25.3678.jpg
#   inflating: 25.3693.jpg
#   inflating: 25.3708.jpg
#   inflating: 25.3734.jpg
#   inflating: 25.3736.jpg
#   inflating: 25.3737.jpg
#   inflating: 25.3763.jpg
#   inflating: 25.3768.jpg
#   inflating: 25.3791.jpg
#   inflating: 25.3863.jpg
#   inflating: 25.3869.jpg
#   inflating: 25.3929.jpg
#   inflating: 25.3938.jpg
#   inflating: 25.3945.jpg
#   inflating: 25.3957.jpg
#   inflating: 25.3963.jpg
#   inflating: 25.3966.jpg
#   inflating: 25.3973.jpg
#   inflating: 25.3988.jpg
#   inflating: 25.3993.jpg
#   inflating: 25.4032.jpg
#   inflating: 25.4061.jpg
#   inflating: 25.41.jpg
#   inflating: 25.4107.jpg
#   inflating: 25.4128.jpg
#   inflating: 25.4133.jpg
#   inflating: 25.4134.jpg
#   inflating: 25.4156.jpg
#   inflating: 25.417.jpg
#   inflating: 25.4243.jpg
#   inflating: 25.4297.jpg
#   inflating: 25.43.jpg
#   inflating: 25.4311.jpg
#   inflating: 25.4349.jpg
#   inflating: 25.4356.jpg
#   inflating: 25.438.jpg
#   inflating: 25.4394.jpg
#   inflating: 25.4449.jpg
#   inflating: 25.4451.jpg
#   inflating: 25.4472.jpg
#   inflating: 25.4534.jpg
#   inflating: 25.4538.jpg
#   inflating: 25.4594.jpg
#   inflating: 25.4601.jpg
#   inflating: 25.4628.jpg
#   inflating: 25.4643.jpg
#   inflating: 25.4647.jpg
#   inflating: 25.4654.jpg
#   inflating: 25.4759.jpg
#   inflating: 25.4765.jpg
#   inflating: 25.48.jpg
#   inflating: 25.4801.jpg
#   inflating: 25.4825.jpg
#   inflating: 25.4839.jpg
#   inflating: 25.4867.jpg
#   inflating: 25.4912.jpg
#   inflating: 25.4921.jpg
#   inflating: 25.4922.jpg
#   inflating: 25.4961.jpg
#   inflating: 25.4964.jpg
#   inflating: 25.5011.jpg
#   inflating: 25.5051.jpg
#   inflating: 25.5052.jpg
#   inflating: 25.5054.jpg
#   inflating: 25.5056.jpg
#   inflating: 25.5082.jpg
#   inflating: 25.5131.jpg
#   inflating: 25.5132.jpg
#   inflating: 25.5134.jpg
#   inflating: 25.5195.jpg
#   inflating: 25.5215.jpg
#   inflating: 25.5228.jpg
#   inflating: 25.5237.jpg
#   inflating: 25.5314.jpg
#   inflating: 25.5315.jpg
#   inflating: 25.534.jpg
#   inflating: 25.5346.jpg
#   inflating: 25.5349.jpg
#   inflating: 25.5357.jpg
#   inflating: 25.5381.jpg
#   inflating: 25.5389.jpg
#   inflating: 25.5391.jpg
#   inflating: 25.5394.jpg
#   inflating: 25.5396.jpg
#   inflating: 25.5402.jpg
#   inflating: 25.5418.jpg
#   inflating: 25.5427.jpg
#   inflating: 25.5444.jpg
#   inflating: 25.5452.jpg
#   inflating: 25.5464.jpg
#   inflating: 25.5474.jpg
#   inflating: 25.5542.jpg
#   inflating: 25.557.jpg
#   inflating: 25.5622.jpg
#   inflating: 25.5655.jpg
#   inflating: 25.5659.jpg
#   inflating: 25.5699.jpg
#   inflating: 25.5715.jpg
#   inflating: 25.5761.jpg
#   inflating: 25.5794.jpg
#   inflating: 25.5823.jpg
#   inflating: 25.5827.jpg
#   inflating: 25.5848.jpg
#   inflating: 25.5851.jpg
#   inflating: 25.5857.jpg
#   inflating: 25.5895.jpg
#   inflating: 25.5903.jpg
#   inflating: 25.591.jpg
#   inflating: 25.5963.jpg
#   inflating: 25.5966.jpg
#   inflating: 25.5974.jpg
#   inflating: 25.601.jpg
#   inflating: 25.6041.jpg
#   inflating: 25.6045.jpg
#   inflating: 25.6051.jpg
#   inflating: 25.6104.jpg
#   inflating: 25.6137.jpg
#   inflating: 25.6145.jpg
#   inflating: 25.6155.jpg
#   inflating: 25.6167.jpg
#   inflating: 25.618.jpg
#   inflating: 25.6182.jpg
#   inflating: 25.6184.jpg
#   inflating: 25.6222.jpg
#   inflating: 25.6233.jpg
#   inflating: 25.6243.jpg
#   inflating: 25.6273.jpg
#   inflating: 25.6283.jpg
#   inflating: 25.6287.jpg
#   inflating: 25.6289.jpg
#   inflating: 25.629.jpg
#   inflating: 25.6311.jpg
#   inflating: 25.6342.jpg
#   inflating: 25.6354.jpg
#   inflating: 25.6357.jpg
#   inflating: 25.6387.jpg
#   inflating: 25.6401.jpg
#   inflating: 25.6402.jpg
#   inflating: 25.6441.jpg
#   inflating: 25.6446.jpg
#   inflating: 25.645.jpg
#   inflating: 25.6453.jpg
#   inflating: 25.6466.jpg
#   inflating: 25.647.jpg
#   inflating: 25.6496.jpg
#   inflating: 25.6523.jpg
#   inflating: 25.6533.jpg
#   inflating: 25.6537.jpg
#   inflating: 25.6538.jpg
#   inflating: 25.6545.jpg
#   inflating: 25.6551.jpg
#   inflating: 25.6561.jpg
#   inflating: 25.657.jpg
#   inflating: 25.6576.jpg
#   inflating: 25.6643.jpg
#   inflating: 25.6659.jpg
#   inflating: 25.6665.jpg
#   inflating: 25.6676.jpg
#   inflating: 25.6678.jpg
#   inflating: 25.6688.jpg
#   inflating: 25.6695.jpg
#   inflating: 25.6705.jpg
#   inflating: 25.677.jpg
#   inflating: 25.6822.jpg
#   inflating: 25.6863.jpg
#   inflating: 25.6877.jpg
#   inflating: 25.6886.jpg
#   inflating: 25.6908.jpg
#   inflating: 25.6955.jpg
#   inflating: 25.6991.jpg
#   inflating: 25.7028.jpg
#   inflating: 25.7038.jpg
#   inflating: 25.7053.jpg
#   inflating: 25.7064.jpg
#   inflating: 25.7096.jpg
#   inflating: 25.7122.jpg
#   inflating: 25.7135.jpg
#   inflating: 25.7205.jpg
#   inflating: 25.7211.jpg
#   inflating: 25.7254.jpg
#   inflating: 25.7256.jpg
#   inflating: 25.727.jpg
#   inflating: 25.7274.jpg
#   inflating: 25.7311.jpg
#   inflating: 25.732.jpg
#   inflating: 25.7324.jpg
#   inflating: 25.7337.jpg
#   inflating: 25.7356.jpg
#   inflating: 25.7372.jpg
#   inflating: 25.7403.jpg
#   inflating: 25.7447.jpg
#   inflating: 25.7456.jpg
#   inflating: 25.746.jpg
#   inflating: 25.7462.jpg
#   inflating: 25.7506.jpg
#   inflating: 25.7546.jpg
#   inflating: 25.7563.jpg
#   inflating: 25.7564.jpg
#   inflating: 25.7601.jpg
#   inflating: 25.7688.jpg
#   inflating: 25.7698.jpg
#   inflating: 25.7708.jpg
#   inflating: 25.7719.jpg
#   inflating: 25.772.jpg
#   inflating: 25.7724.jpg
#   inflating: 25.7791.jpg
#   inflating: 25.7793.jpg
#   inflating: 25.7808.jpg
#   inflating: 25.7812.jpg
#   inflating: 25.7846.jpg
#   inflating: 25.7852.jpg
#   inflating: 25.7856.jpg
#   inflating: 25.7867.jpg
#   inflating: 25.7869.jpg
#   inflating: 25.7897.jpg
#   inflating: 25.7946.jpg
#   inflating: 25.7991.jpg
#   inflating: 25.8017.jpg
#   inflating: 25.8028.jpg
#   inflating: 25.8039.jpg
#   inflating: 25.8046.jpg
#   inflating: 25.805.jpg
#   inflating: 25.8056.jpg
#   inflating: 25.8062.jpg
#   inflating: 25.8075.jpg
#   inflating: 25.8076.jpg
#   inflating: 25.8078.jpg
#   inflating: 25.8158.jpg
#   inflating: 25.8164.jpg
#   inflating: 25.8181.jpg
#   inflating: 25.8182.jpg
#   inflating: 25.8223.jpg
#   inflating: 25.8247.jpg
#   inflating: 25.8248.jpg
#   inflating: 25.8301.jpg
#   inflating: 25.8309.jpg
#   inflating: 25.8325.jpg
#   inflating: 25.8326.jpg
#   inflating: 25.8337.jpg
#   inflating: 25.8352.jpg
#   inflating: 25.8353.jpg
#   inflating: 25.8367.jpg
#   inflating: 25.8375.jpg
#   inflating: 25.8393.jpg
#   inflating: 25.8402.jpg
#   inflating: 25.8415.jpg
#   inflating: 25.8436.jpg
#   inflating: 25.8439.jpg
#   inflating: 25.8483.jpg
#   inflating: 25.8486.jpg
#   inflating: 25.8487.jpg
#   inflating: 25.8491.jpg
#   inflating: 25.8549.jpg
#   inflating: 25.8558.jpg
#   inflating: 25.8576.jpg
#   inflating: 25.8579.jpg
#   inflating: 25.8584.jpg
#   inflating: 25.8587.jpg
#   inflating: 25.8628.jpg
#   inflating: 25.8719.jpg
#   inflating: 25.8739.jpg
#   inflating: 25.8762.jpg
#   inflating: 25.8774.jpg
#   inflating: 25.8789.jpg
#   inflating: 25.8805.jpg
#   inflating: 25.8813.jpg
#   inflating: 25.882.jpg
#   inflating: 25.8822.jpg
#   inflating: 25.8851.jpg
#   inflating: 25.8922.jpg
#   inflating: 25.8929.jpg
#   inflating: 25.8966.jpg
#   inflating: 25.8987.jpg
#   inflating: 25.8998.jpg
#   inflating: 25.8999.jpg
#   inflating: 25.9.jpg
#   inflating: 25.901.jpg
#   inflating: 25.9033.jpg
#   inflating: 25.9056.jpg
#   inflating: 25.9065.jpg
#   inflating: 25.9073.jpg
#   inflating: 25.9117.jpg
#   inflating: 25.9144.jpg
#   inflating: 25.9169.jpg
#   inflating: 25.9195.jpg
#   inflating: 25.9208.jpg
#   inflating: 25.9223.jpg
#   inflating: 25.9224.jpg
#   inflating: 25.9241.jpg
#   inflating: 25.9242.jpg
#   inflating: 25.9258.jpg
#   inflating: 25.927.jpg
#   inflating: 25.9271.jpg
#   inflating: 25.9294.jpg
#   inflating: 25.9306.jpg
#   inflating: 25.9307.jpg
#   inflating: 25.9315.jpg
#   inflating: 25.9325.jpg
#   inflating: 25.9362.jpg
#   inflating: 25.9371.jpg
#   inflating: 25.9381.jpg
#   inflating: 25.9394.jpg
#   inflating: 25.9401.jpg
#   inflating: 25.9418.jpg
#   inflating: 25.9455.jpg
#   inflating: 25.9464.jpg
#   inflating: 25.9466.jpg
#   inflating: 25.9471.jpg
#   inflating: 25.9514.jpg
#   inflating: 25.9538.jpg
#   inflating: 25.9553.jpg
#   inflating: 25.958.jpg
#   inflating: 25.9605.jpg
#   inflating: 25.9626.jpg
#   inflating: 25.9704.jpg
#   inflating: 25.9768.jpg
#   inflating: 25.9772.jpg
#   inflating: 25.9815.jpg
#   inflating: 25.9826.jpg
#   inflating: 25.9828.jpg
#   inflating: 25.9831.jpg
#   inflating: 25.9845.jpg
#   inflating: 25.9851.jpg
#   inflating: 25.9883.jpg
#   inflating: 25.9899.jpg
#   inflating: 25.9908.jpg
#   inflating: 25.9931.jpg
#   inflating: 25.9943.jpg
#   inflating: 25.9953.jpg
#   inflating: 25.9972.jpg
#   inflating: 25.9973.jpg
#   inflating: 25.9987.jpg
#   inflating: 26.0022.jpg
#   inflating: 26.0055.jpg
#   inflating: 26.0058.jpg
#   inflating: 26.0108.jpg
#   inflating: 26.0128.jpg
#   inflating: 26.017.jpg
#   inflating: 26.0176.jpg
#   inflating: 26.0215.jpg
#   inflating: 26.0227.jpg
#   inflating: 26.0255.jpg
#   inflating: 26.0285.jpg
#   inflating: 26.0293.jpg
#   inflating: 26.0324.jpg
#   inflating: 26.0335.jpg
#   inflating: 26.0342.jpg
#   inflating: 26.036.jpg
#   inflating: 26.0392.jpg
#   inflating: 26.0401.jpg
#   inflating: 26.0438.jpg
#   inflating: 26.0458.jpg
#   inflating: 26.0469.jpg
#   inflating: 26.0472.jpg
#   inflating: 26.0499.jpg
#   inflating: 26.051.jpg
#   inflating: 26.0535.jpg
#   inflating: 26.0542.jpg
#   inflating: 26.0605.jpg
#   inflating: 26.0612.jpg
#   inflating: 26.0633.jpg
#   inflating: 26.0638.jpg
#   inflating: 26.064.jpg
#   inflating: 26.0648.jpg
#   inflating: 26.067.jpg
#   inflating: 26.0673.jpg
#   inflating: 26.0687.jpg
#   inflating: 26.0691.jpg
#   inflating: 26.0698.jpg
#   inflating: 26.0709.jpg
#   inflating: 26.0729.jpg
#   inflating: 26.0745.jpg
#   inflating: 26.0753.jpg
#   inflating: 26.0784.jpg
#   inflating: 26.0797.jpg
#   inflating: 26.0815.jpg
#   inflating: 26.0833.jpg
#   inflating: 26.0841.jpg
#   inflating: 26.0872.jpg
#   inflating: 26.092.jpg
#   inflating: 26.0922.jpg
#   inflating: 26.0925.jpg
#   inflating: 26.0945.jpg
#   inflating: 26.0956.jpg
#   inflating: 26.0963.jpg
#   inflating: 26.0985.jpg
#   inflating: 26.1002.jpg
#   inflating: 26.1038.jpg
#   inflating: 26.1042.jpg
#   inflating: 26.1113.jpg
#   inflating: 26.12.jpg
#   inflating: 26.1204.jpg
#   inflating: 26.1239.jpg
#   inflating: 26.1281.jpg
#   inflating: 26.1323.jpg
#   inflating: 26.1324.jpg
#   inflating: 26.1326.jpg
#   inflating: 26.1371.jpg
#   inflating: 26.1375.jpg
#   inflating: 26.1392.jpg
#   inflating: 26.1407.jpg
#   inflating: 26.1432.jpg
#   inflating: 26.1467.jpg
#   inflating: 26.1474.jpg
#   inflating: 26.1531.jpg
#   inflating: 26.1548.jpg
#   inflating: 26.1555.jpg
#   inflating: 26.1669.jpg
#   inflating: 26.1671.jpg
#   inflating: 26.1679.jpg
#   inflating: 26.1683.jpg
#   inflating: 26.1736.jpg
#   inflating: 26.1766.jpg
#   inflating: 26.1774.jpg
#   inflating: 26.1797.jpg
#   inflating: 26.1801.jpg
#   inflating: 26.1838.jpg
#   inflating: 26.1882.jpg
#   inflating: 26.1885.jpg
#   inflating: 26.1886.jpg
#   inflating: 26.1901.jpg
#   inflating: 26.1936.jpg
#   inflating: 26.1971.jpg
#   inflating: 26.1985.jpg
#   inflating: 26.1998.jpg
#   inflating: 26.2001.jpg
#   inflating: 26.2023.jpg
#   inflating: 26.2025.jpg
#   inflating: 26.2028.jpg
#   inflating: 26.2037.jpg
#   inflating: 26.209.jpg
#   inflating: 26.2111.jpg
#   inflating: 26.2127.jpg
#   inflating: 26.217.jpg
#   inflating: 26.2211.jpg
#   inflating: 26.2226.jpg
#   inflating: 26.2241.jpg
#   inflating: 26.2246.jpg
#   inflating: 26.2296.jpg
#   inflating: 26.2297.jpg
#   inflating: 26.2302.jpg
#   inflating: 26.2303.jpg
#   inflating: 26.2305.jpg
#   inflating: 26.2319.jpg
#   inflating: 26.2365.jpg
#   inflating: 26.2373.jpg
#   inflating: 26.2385.jpg
#   inflating: 26.2416.jpg
#   inflating: 26.2447.jpg
#   inflating: 26.2597.jpg
#   inflating: 26.2625.jpg
#   inflating: 26.2635.jpg
#   inflating: 26.2646.jpg
#   inflating: 26.2705.jpg
#   inflating: 26.276.jpg
#   inflating: 26.2784.jpg
#   inflating: 26.2835.jpg
#   inflating: 26.2844.jpg
#   inflating: 26.2859.jpg
#   inflating: 26.2877.jpg
#   inflating: 26.288.jpg
#   inflating: 26.2898.jpg
#   inflating: 26.2951.jpg
#   inflating: 26.2973.jpg
#   inflating: 26.2987.jpg
#   inflating: 26.3063.jpg
#   inflating: 26.3069.jpg
#   inflating: 26.3079.jpg
#   inflating: 26.309.jpg
#   inflating: 26.3099.jpg
#   inflating: 26.3102.jpg
#   inflating: 26.3113.jpg
#   inflating: 26.3154.jpg
#   inflating: 26.3164.jpg
#   inflating: 26.3187.jpg
#   inflating: 26.3199.jpg
#   inflating: 26.3235.jpg
#   inflating: 26.3249.jpg
#   inflating: 26.3297.jpg
#   inflating: 26.33.jpg
#   inflating: 26.3307.jpg
#   inflating: 26.3421.jpg
#   inflating: 26.343.jpg
#   inflating: 26.3446.jpg
#   inflating: 26.3483.jpg
#   inflating: 26.3515.jpg
#   inflating: 26.3517.jpg
#   inflating: 26.3518.jpg
#   inflating: 26.3521.jpg
#   inflating: 26.3526.jpg
#   inflating: 26.3537.jpg
#   inflating: 26.3548.jpg
#   inflating: 26.3554.jpg
#   inflating: 26.3586.jpg
#   inflating: 26.3636.jpg
#   inflating: 26.3642.jpg
#   inflating: 26.365.jpg
#   inflating: 26.3696.jpg
#   inflating: 26.3698.jpg
#   inflating: 26.3702.jpg
#   inflating: 26.3713.jpg
#   inflating: 26.3724.jpg
#   inflating: 26.3735.jpg
#   inflating: 26.3742.jpg
#   inflating: 26.3744.jpg
#   inflating: 26.3761.jpg
#   inflating: 26.3762.jpg
#   inflating: 26.3773.jpg
#   inflating: 26.3776.jpg
#   inflating: 26.3785.jpg
#   inflating: 26.3856.jpg
#   inflating: 26.3861.jpg
#   inflating: 26.3874.jpg
#   inflating: 26.3894.jpg
#   inflating: 26.3909.jpg
#   inflating: 26.3914.jpg
#   inflating: 26.3922.jpg
#   inflating: 26.3923.jpg
#   inflating: 26.3933.jpg
#   inflating: 26.3934.jpg
#   inflating: 26.3935.jpg
#   inflating: 26.3951.jpg
#   inflating: 26.3954.jpg
#   inflating: 26.3985.jpg
#   inflating: 26.3991.jpg
#   inflating: 26.3998.jpg
#   inflating: 26.4.jpg
#   inflating: 26.4017.jpg
#   inflating: 26.4019.jpg
#   inflating: 26.4042.jpg
#   inflating: 26.4045.jpg
#   inflating: 26.4128.jpg
#   inflating: 26.4135.jpg
#   inflating: 26.4153.jpg
#   inflating: 26.4179.jpg
#   inflating: 26.4209.jpg
#   inflating: 26.4221.jpg
#   inflating: 26.4262.jpg
#   inflating: 26.4277.jpg
#   inflating: 26.4347.jpg
#   inflating: 26.436.jpg
#   inflating: 26.4389.jpg
#   inflating: 26.4402.jpg
#   inflating: 26.4431.jpg
#   inflating: 26.4433.jpg
#   inflating: 26.4435.jpg
#   inflating: 26.4458.jpg
#   inflating: 26.449.jpg
#   inflating: 26.451.jpg
#   inflating: 26.4523.jpg
#   inflating: 26.4576.jpg
#   inflating: 26.4583.jpg
#   inflating: 26.4632.jpg
#   inflating: 26.4644.jpg
#   inflating: 26.4653.jpg
#   inflating: 26.4665.jpg
#   inflating: 26.4669.jpg
#   inflating: 26.467.jpg
#   inflating: 26.4698.jpg
#   inflating: 26.4725.jpg
#   inflating: 26.4736.jpg
#   inflating: 26.4789.jpg
#   inflating: 26.4797.jpg
#   inflating: 26.4859.jpg
#   inflating: 26.486.jpg
#   inflating: 26.4886.jpg
#   inflating: 26.489.jpg
#   inflating: 26.4905.jpg
#   inflating: 26.493.jpg
#   inflating: 26.4968.jpg
#   inflating: 26.4989.jpg
#   inflating: 26.4993.jpg
#   inflating: 26.4997.jpg
#   inflating: 26.5031.jpg
#   inflating: 26.506.jpg
#   inflating: 26.507.jpg
#   inflating: 26.5087.jpg
#   inflating: 26.5093.jpg
#   inflating: 26.5099.jpg
#   inflating: 26.51.jpg
#   inflating: 26.5105.jpg
#   inflating: 26.5109.jpg
#   inflating: 26.5133.jpg
#   inflating: 26.5169.jpg
#   inflating: 26.517.jpg
#   inflating: 26.5187.jpg
#   inflating: 26.5224.jpg
#   inflating: 26.5234.jpg
#   inflating: 26.5235.jpg
#   inflating: 26.5236.jpg
#   inflating: 26.5237.jpg
#   inflating: 26.5251.jpg
#   inflating: 26.5253.jpg
#   inflating: 26.5256.jpg
#   inflating: 26.5258.jpg
#   inflating: 26.5262.jpg
#   inflating: 26.527.jpg
#   inflating: 26.5291.jpg
#   inflating: 26.5293.jpg
#   inflating: 26.532.jpg
#   inflating: 26.5321.jpg
#   inflating: 26.5324.jpg
#   inflating: 26.5359.jpg
#   inflating: 26.5377.jpg
#   inflating: 26.5414.jpg
#   inflating: 26.5429.jpg
#   inflating: 26.5433.jpg
#   inflating: 26.5444.jpg
#   inflating: 26.5465.jpg
#   inflating: 26.548.jpg
#   inflating: 26.5483.jpg
#   inflating: 26.5488.jpg
#   inflating: 26.5492.jpg
#   inflating: 26.5521.jpg
#   inflating: 26.5528.jpg
#   inflating: 26.5532.jpg
#   inflating: 26.5545.jpg
#   inflating: 26.555.jpg
#   inflating: 26.5581.jpg
#   inflating: 26.559.jpg
#   inflating: 26.5601.jpg
#   inflating: 26.5611.jpg
#   inflating: 26.5612.jpg
#   inflating: 26.5615.jpg
#   inflating: 26.5658.jpg
#   inflating: 26.5659.jpg
#   inflating: 26.5693.jpg
#   inflating: 26.5699.jpg
#   inflating: 26.5706.jpg
#   inflating: 26.5708.jpg
#   inflating: 26.5717.jpg
#   inflating: 26.5756.jpg
#   inflating: 26.5757.jpg
#   inflating: 26.5761.jpg
#   inflating: 26.579.jpg
#   inflating: 26.5794.jpg
#   inflating: 26.5802.jpg
#   inflating: 26.5818.jpg
#   inflating: 26.5831.jpg
#   inflating: 26.5832.jpg
#   inflating: 26.5843.jpg
#   inflating: 26.5863.jpg
#   inflating: 26.5882.jpg
#   inflating: 26.5887.jpg
#   inflating: 26.5911.jpg
#   inflating: 26.5933.jpg
#   inflating: 26.5959.jpg
#   inflating: 26.5971.jpg
#   inflating: 26.5993.jpg
#   inflating: 26.6017.jpg
#   inflating: 26.6029.jpg
#   inflating: 26.6048.jpg
#   inflating: 26.6057.jpg
#   inflating: 26.6106.jpg
#   inflating: 26.611.jpg
#   inflating: 26.6113.jpg
#   inflating: 26.6166.jpg
#   inflating: 26.6175.jpg
#   inflating: 26.6181.jpg
#   inflating: 26.6212.jpg
#   inflating: 26.6249.jpg
#   inflating: 26.6266.jpg
#   inflating: 26.6281.jpg
#   inflating: 26.6304.jpg
#   inflating: 26.631.jpg
#   inflating: 26.6332.jpg
#   inflating: 26.6338.jpg
#   inflating: 26.6362.jpg
#   inflating: 26.6412.jpg
#   inflating: 26.6432.jpg
#   inflating: 26.6446.jpg
#   inflating: 26.6451.jpg
#   inflating: 26.6545.jpg
#   inflating: 26.6559.jpg
#   inflating: 26.6598.jpg
#   inflating: 26.6603.jpg
#   inflating: 26.6624.jpg
#   inflating: 26.6697.jpg
#   inflating: 26.6701.jpg
#   inflating: 26.6703.jpg
#   inflating: 26.671.jpg
#   inflating: 26.6725.jpg
#   inflating: 26.6762.jpg
#   inflating: 26.6765.jpg
#   inflating: 26.6792.jpg
#   inflating: 26.6815.jpg
#   inflating: 26.6816.jpg
#   inflating: 26.6849.jpg
#   inflating: 26.6868.jpg
#   inflating: 26.6883.jpg
#   inflating: 26.6885.jpg
#   inflating: 26.6895.jpg
#   inflating: 26.6906.jpg
#   inflating: 26.6926.jpg
#   inflating: 26.6943.jpg
#   inflating: 26.6982.jpg
#   inflating: 26.7007.jpg
#   inflating: 26.7022.jpg
#   inflating: 26.7024.jpg
#   inflating: 26.7031.jpg
#   inflating: 26.7049.jpg
#   inflating: 26.705.jpg
#   inflating: 26.7084.jpg
#   inflating: 26.7112.jpg
#   inflating: 26.7125.jpg
#   inflating: 26.7142.jpg
#   inflating: 26.7151.jpg
#   inflating: 26.7171.jpg
#   inflating: 26.7176.jpg
#   inflating: 26.7185.jpg
#   inflating: 26.7214.jpg
#   inflating: 26.7235.jpg
#   inflating: 26.7243.jpg
#   inflating: 26.7248.jpg
#   inflating: 26.7255.jpg
#   inflating: 26.7276.jpg
#   inflating: 26.73.jpg
#   inflating: 26.731.jpg
#   inflating: 26.7311.jpg
#   inflating: 26.7342.jpg
#   inflating: 26.7356.jpg
#   inflating: 26.7384.jpg
#   inflating: 26.7415.jpg
#   inflating: 26.7445.jpg
#   inflating: 26.7447.jpg
#   inflating: 26.745.jpg
#   inflating: 26.7458.jpg
#   inflating: 26.7463.jpg
#   inflating: 26.7473.jpg
#   inflating: 26.7493.jpg
#   inflating: 26.7517.jpg
#   inflating: 26.7559.jpg
#   inflating: 26.7582.jpg
#   inflating: 26.7607.jpg
#   inflating: 26.7631.jpg
#   inflating: 26.7694.jpg
#   inflating: 26.7708.jpg
#   inflating: 26.772.jpg
#   inflating: 26.7766.jpg
#   inflating: 26.7772.jpg
#   inflating: 26.7835.jpg
#   inflating: 26.7852.jpg
#   inflating: 26.7867.jpg
#   inflating: 26.7868.jpg
#   inflating: 26.7906.jpg
#   inflating: 26.7911.jpg
#   inflating: 26.7927.jpg
#   inflating: 26.7932.jpg
#   inflating: 26.796.jpg
#   inflating: 26.799.jpg
#   inflating: 26.8022.jpg
#   inflating: 26.8027.jpg
#   inflating: 26.8042.jpg
#   inflating: 26.807.jpg
#   inflating: 26.8084.jpg
#   inflating: 26.809.jpg
#   inflating: 26.813.jpg
#   inflating: 26.8155.jpg
#   inflating: 26.8163.jpg
#   inflating: 26.8171.jpg
#   inflating: 26.8172.jpg
#   inflating: 26.8206.jpg
#   inflating: 26.8218.jpg
#   inflating: 26.8256.jpg
#   inflating: 26.8265.jpg
#   inflating: 26.827.jpg
#   inflating: 26.8277.jpg
#   inflating: 26.8279.jpg
#   inflating: 26.8295.jpg
#   inflating: 26.8302.jpg
#   inflating: 26.831.jpg
#   inflating: 26.8329.jpg
#   inflating: 26.8337.jpg
#   inflating: 26.8339.jpg
#   inflating: 26.8351.jpg
#   inflating: 26.8352.jpg
#   inflating: 26.8372.jpg
#   inflating: 26.85.jpg
#   inflating: 26.8532.jpg
#   inflating: 26.8563.jpg
#   inflating: 26.8577.jpg
#   inflating: 26.8578.jpg
#   inflating: 26.8603.jpg
#   inflating: 26.8615.jpg
#   inflating: 26.8617.jpg
#   inflating: 26.8638.jpg
#   inflating: 26.8656.jpg
#   inflating: 26.8708.jpg
#   inflating: 26.8727.jpg
#   inflating: 26.8736.jpg
#   inflating: 26.8742.jpg
#   inflating: 26.8758.jpg
#   inflating: 26.8821.jpg
#   inflating: 26.886.jpg
#   inflating: 26.8874.jpg
#   inflating: 26.8888.jpg
#   inflating: 26.889.jpg
#   inflating: 26.8913.jpg
#   inflating: 26.8915.jpg
#   inflating: 26.8916.jpg
#   inflating: 26.8945.jpg
#   inflating: 26.8949.jpg
#   inflating: 26.8975.jpg
#   inflating: 26.8976.jpg
#   inflating: 26.8991.jpg
#   inflating: 26.8993.jpg
#   inflating: 26.9018.jpg
#   inflating: 26.9058.jpg
#   inflating: 26.9077.jpg
#   inflating: 26.908.jpg
#   inflating: 26.9082.jpg
#   inflating: 26.909.jpg
#   inflating: 26.9119.jpg
#   inflating: 26.9148.jpg
#   inflating: 26.9162.jpg
#   inflating: 26.9186.jpg
#   inflating: 26.9201.jpg
#   inflating: 26.9213.jpg
#   inflating: 26.9233.jpg
#   inflating: 26.9234.jpg
#   inflating: 26.9258.jpg
#   inflating: 26.9262.jpg
#   inflating: 26.9318.jpg
#   inflating: 26.9336.jpg
#   inflating: 26.9346.jpg
#   inflating: 26.9365.jpg
#   inflating: 26.9368.jpg
#   inflating: 26.9394.jpg
#   inflating: 26.9397.jpg
#   inflating: 26.9404.jpg
#   inflating: 26.9456.jpg
#   inflating: 26.9478.jpg
#   inflating: 26.9499.jpg
#   inflating: 26.9505.jpg
# ...
#   inflating: 28.9783.jpg
#   inflating: 28.9784.jpg
#   inflating: 28.9789.jpg
#   inflating: 28.9818.jpg
#   inflating: 28.9819.jpg
#   inflating: 28.9827.jpg
#   inflating: 28.9834.jpg
#   inflating: 28.9837.jpg
#   inflating: 28.9888.jpg
#   inflating: 28.9891.jpg
#   inflating: 28.9923.jpg
#   inflating: 28.9927.jpg
#   inflating: 28.9933.jpg
#   inflating: 28.9935.jpg
#   inflating: 28.9938.jpg
#   inflating: 28.9956.jpg
#   inflating: 28.9958.jpg
#   inflating: 28.9961.jpg
#   inflating: 28.9997.jpg
#   inflating: 29.0008.jpg
#   inflating: 29.0013.jpg
#   inflating: 29.0022.jpg
#   inflating: 29.0031.jpg
#   inflating: 29.0047.jpg
#   inflating: 29.0057.jpg
#   inflating: 29.0062.jpg
#   inflating: 29.0077.jpg
#   inflating: 29.0112.jpg
#   inflating: 29.0114.jpg
#   inflating: 29.0165.jpg
#   inflating: 29.0175.jpg
#   inflating: 29.0177.jpg
#   inflating: 29.0188.jpg
#   inflating: 29.0214.jpg
#   inflating: 29.022.jpg
#   inflating: 29.0253.jpg
#   inflating: 29.0256.jpg
#   inflating: 29.0258.jpg
#   inflating: 29.0265.jpg
#   inflating: 29.0267.jpg
#   inflating: 29.0277.jpg
#   inflating: 29.0285.jpg
#   inflating: 29.0297.jpg
#   inflating: 29.0339.jpg
#   inflating: 29.035.jpg
#   inflating: 29.0378.jpg
#   inflating: 29.0384.jpg
#   inflating: 29.0406.jpg
#   inflating: 29.0418.jpg
#   inflating: 29.0424.jpg
#   inflating: 29.0426.jpg
#   inflating: 29.0428.jpg
#   inflating: 29.0436.jpg
#   inflating: 29.0483.jpg
#   inflating: 29.0496.jpg
#   inflating: 29.0507.jpg
#   inflating: 29.051.jpg
#   inflating: 29.0563.jpg
#   inflating: 29.0567.jpg
#   inflating: 29.0672.jpg
#   inflating: 29.0683.jpg
#   inflating: 29.0699.jpg
#   inflating: 29.0712.jpg
#   inflating: 29.0713.jpg
#   inflating: 29.0731.jpg
#   inflating: 29.079.jpg
#   inflating: 29.0814.jpg
#   inflating: 29.0851.jpg
#   inflating: 29.0894.jpg
#   inflating: 29.0908.jpg
#   inflating: 29.0916.jpg
#   inflating: 29.0919.jpg
#   inflating: 29.0921.jpg
#   inflating: 29.0935.jpg
#   inflating: 29.0936.jpg
#   inflating: 29.0948.jpg
#   inflating: 29.0955.jpg
#   inflating: 29.0977.jpg
#   inflating: 29.0986.jpg
#   inflating: 29.0988.jpg
#   inflating: 29.1044.jpg
#   inflating: 29.1087.jpg
#   inflating: 29.1099.jpg
#   inflating: 29.1103.jpg
#   inflating: 29.1104.jpg
#   inflating: 29.1173.jpg
#   inflating: 29.1188.jpg
#   inflating: 29.1193.jpg
#   inflating: 29.1241.jpg
#   inflating: 29.1243.jpg
#   inflating: 29.1251.jpg
#   inflating: 29.1256.jpg
#   inflating: 29.1257.jpg
#   inflating: 29.1266.jpg
#   inflating: 29.1268.jpg
#   inflating: 29.1281.jpg
#   inflating: 29.1294.jpg
#   inflating: 29.1304.jpg
#   inflating: 29.1305.jpg
#   inflating: 29.1324.jpg
#   inflating: 29.1351.jpg
#   inflating: 29.137.jpg
#   inflating: 29.1407.jpg
#   inflating: 29.1415.jpg
#   inflating: 29.1426.jpg
#   inflating: 29.1439.jpg
#   inflating: 29.1461.jpg
#   inflating: 29.1474.jpg
#   inflating: 29.1504.jpg
#   inflating: 29.1507.jpg
#   inflating: 29.1509.jpg
#   inflating: 29.1521.jpg
#   inflating: 29.1523.jpg
#   inflating: 29.1532.jpg
#   inflating: 29.1553.jpg
#   inflating: 29.1581.jpg
#   inflating: 29.1593.jpg
#   inflating: 29.1597.jpg
#   inflating: 29.1631.jpg
#   inflating: 29.1634.jpg
#   inflating: 29.1656.jpg
#   inflating: 29.1662.jpg
#   inflating: 29.167.jpg
#   inflating: 29.1678.jpg
#   inflating: 29.1683.jpg
#   inflating: 29.1726.jpg
#   inflating: 29.1729.jpg
#   inflating: 29.1738.jpg
#   inflating: 29.1757.jpg
#   inflating: 29.1761.jpg
#   inflating: 29.1762.jpg
#   inflating: 29.1775.jpg
#   inflating: 29.1787.jpg
#   inflating: 29.1807.jpg
#   inflating: 29.1812.jpg
#   inflating: 29.1826.jpg
#   inflating: 29.1827.jpg
#   inflating: 29.1828.jpg
#   inflating: 29.1831.jpg
#   inflating: 29.1896.jpg
#   inflating: 29.1918.jpg
#   inflating: 29.1951.jpg
#   inflating: 29.1992.jpg
#   inflating: 29.2001.jpg
#   inflating: 29.2005.jpg
#   inflating: 29.2013.jpg
#   inflating: 29.2014.jpg
#   inflating: 29.2031.jpg
#   inflating: 29.2047.jpg
#   inflating: 29.2071.jpg
#   inflating: 29.2073.jpg
#   inflating: 29.213.jpg
#   inflating: 29.2145.jpg
#   inflating: 29.2146.jpg
#   inflating: 29.2176.jpg
#   inflating: 29.222.jpg
#   inflating: 29.2245.jpg
#   inflating: 29.2279.jpg
#   inflating: 29.2283.jpg
#   inflating: 29.2296.jpg
#   inflating: 29.2307.jpg
#   inflating: 29.2331.jpg
#   inflating: 29.2332.jpg
#   inflating: 29.2335.jpg
#   inflating: 29.2343.jpg
#   inflating: 29.2369.jpg
#   inflating: 29.237.jpg
#   inflating: 29.2371.jpg
#   inflating: 29.2386.jpg
#   inflating: 29.2388.jpg
#   inflating: 29.2395.jpg
#   inflating: 29.2399.jpg
#   inflating: 29.2409.jpg
#   inflating: 29.2418.jpg
#   inflating: 29.2447.jpg
#   inflating: 29.2469.jpg
#   inflating: 29.2477.jpg
#   inflating: 29.2488.jpg
#   inflating: 29.2494.jpg
#   inflating: 29.2508.jpg
#   inflating: 29.2516.jpg
#   inflating: 29.2518.jpg
#   inflating: 29.2525.jpg
#   inflating: 29.2539.jpg
#   inflating: 29.2544.jpg
#   inflating: 29.2555.jpg
#   inflating: 29.2561.jpg
#   inflating: 29.2566.jpg
#   inflating: 29.2568.jpg
#   inflating: 29.2586.jpg
#   inflating: 29.2588.jpg
#   inflating: 29.2589.jpg
#   inflating: 29.2591.jpg
#   inflating: 29.2603.jpg
#   inflating: 29.2615.jpg
#   inflating: 29.2619.jpg
#   inflating: 29.2627.jpg
#   inflating: 29.2628.jpg
#   inflating: 29.2645.jpg
#   inflating: 29.2647.jpg
#   inflating: 29.265.jpg
#   inflating: 29.2662.jpg
#   inflating: 29.2675.jpg
#   inflating: 29.2676.jpg
#   inflating: 29.2696.jpg
#   inflating: 29.2755.jpg
#   inflating: 29.2813.jpg
#   inflating: 29.2814.jpg
#   inflating: 29.2857.jpg
#   inflating: 29.2858.jpg
#   inflating: 29.2946.jpg
#   inflating: 29.295.jpg
#   inflating: 29.2957.jpg
#   inflating: 29.297.jpg
#   inflating: 29.3001.jpg
#   inflating: 29.3039.jpg
#   inflating: 29.3049.jpg
#   inflating: 29.3063.jpg
#   inflating: 29.3066.jpg
#   inflating: 29.3076.jpg
#   inflating: 29.3077.jpg
#   inflating: 29.3081.jpg
#   inflating: 29.3083.jpg
#   inflating: 29.3084.jpg
#   inflating: 29.3093.jpg
#   inflating: 29.3101.jpg
#   inflating: 29.3108.jpg
#   inflating: 29.3113.jpg
#   inflating: 29.3142.jpg
#   inflating: 29.3143.jpg
#   inflating: 29.3144.jpg
#   inflating: 29.3152.jpg
#   inflating: 29.3156.jpg
#   inflating: 29.3186.jpg
#   inflating: 29.3225.jpg
#   inflating: 29.3232.jpg
#   inflating: 29.3245.jpg
#   inflating: 29.3274.jpg
#   inflating: 29.3279.jpg
#   inflating: 29.3284.jpg
#   inflating: 29.3299.jpg
#   inflating: 29.3302.jpg
#   inflating: 29.3307.jpg
#   inflating: 29.331.jpg
#   inflating: 29.3313.jpg
#   inflating: 29.3314.jpg
#   inflating: 29.3406.jpg
#   inflating: 29.3414.jpg
#   inflating: 29.3421.jpg
#   inflating: 29.3436.jpg
#   inflating: 29.3459.jpg
#   inflating: 29.3465.jpg
#   inflating: 29.3537.jpg
#   inflating: 29.354.jpg
#   inflating: 29.3571.jpg
#   inflating: 29.3589.jpg
#   inflating: 29.3595.jpg
#   inflating: 29.3599.jpg
#   inflating: 29.3613.jpg
#   inflating: 29.3647.jpg
#   inflating: 29.3675.jpg
#   inflating: 29.3683.jpg
#   inflating: 29.3692.jpg
#   inflating: 29.3742.jpg
#   inflating: 29.3748.jpg
#   inflating: 29.3758.jpg
#   inflating: 29.3763.jpg
#   inflating: 29.3768.jpg
#   inflating: 29.3772.jpg
#   inflating: 29.3775.jpg
#   inflating: 29.3778.jpg
#   inflating: 29.3784.jpg
#   inflating: 29.3802.jpg
#   inflating: 29.3809.jpg
#   inflating: 29.3813.jpg
#   inflating: 29.3835.jpg
#   inflating: 29.3884.jpg
#   inflating: 29.3899.jpg
#   inflating: 29.3918.jpg
#   inflating: 29.3921.jpg
#   inflating: 29.3941.jpg
#   inflating: 29.3949.jpg
#   inflating: 29.3963.jpg
#   inflating: 29.3966.jpg
#   inflating: 29.398.jpg
#   inflating: 29.3985.jpg
#   inflating: 29.4001.jpg
#   inflating: 29.4021.jpg
#   inflating: 29.4031.jpg
#   inflating: 29.4055.jpg
#   inflating: 29.4064.jpg
#   inflating: 29.4077.jpg
#   inflating: 29.4082.jpg
#   inflating: 29.409.jpg
#   inflating: 29.4091.jpg
#   inflating: 29.4105.jpg
#   inflating: 29.4138.jpg
#   inflating: 29.4155.jpg
#   inflating: 29.4156.jpg
#   inflating: 29.4166.jpg
#   inflating: 29.4178.jpg
#   inflating: 29.4246.jpg
#   inflating: 29.4253.jpg
#   inflating: 29.426.jpg
#   inflating: 29.4265.jpg
#   inflating: 29.429.jpg
#   inflating: 29.4292.jpg
#   inflating: 29.4293.jpg
#   inflating: 29.4298.jpg
#   inflating: 29.4343.jpg
#   inflating: 29.435.jpg
#   inflating: 29.4374.jpg
#   inflating: 29.4375.jpg
#   inflating: 29.4382.jpg
#   inflating: 29.4392.jpg
#   inflating: 29.4427.jpg
#   inflating: 29.4454.jpg
#   inflating: 29.4456.jpg
#   inflating: 29.4465.jpg
#   inflating: 29.4469.jpg
#   inflating: 29.4471.jpg
#   inflating: 29.4476.jpg
#   inflating: 29.4478.jpg
#   inflating: 29.4504.jpg
#   inflating: 29.4513.jpg
#   inflating: 29.4524.jpg
#   inflating: 29.4526.jpg
#   inflating: 29.4531.jpg
#   inflating: 29.4567.jpg
#   inflating: 29.4582.jpg
#   inflating: 29.4592.jpg
#   inflating: 29.4611.jpg
#   inflating: 29.4617.jpg
#   inflating: 29.4665.jpg
#   inflating: 29.4668.jpg
#   inflating: 29.4686.jpg
#   inflating: 29.4688.jpg
#   inflating: 29.4692.jpg
#   inflating: 29.4715.jpg
#   inflating: 29.4729.jpg
#   inflating: 29.477.jpg
#   inflating: 29.4782.jpg
#   inflating: 29.4796.jpg
#   inflating: 29.4836.jpg
#   inflating: 29.4847.jpg
#   inflating: 29.4855.jpg
#   inflating: 29.4868.jpg
#   inflating: 29.4874.jpg
#   inflating: 29.4875.jpg
#   inflating: 29.489.jpg
#   inflating: 29.4914.jpg
#   inflating: 29.4934.jpg
#   inflating: 29.4944.jpg
#   inflating: 29.4949.jpg
#   inflating: 29.4968.jpg
#   inflating: 29.497.jpg
#   inflating: 29.4986.jpg
#   inflating: 29.4997.jpg
#   inflating: 29.5021.jpg
#   inflating: 29.5026.jpg
#   inflating: 29.505.jpg
#   inflating: 29.5102.jpg
#   inflating: 29.5112.jpg
#   inflating: 29.5117.jpg
#   inflating: 29.5123.jpg
#   inflating: 29.5157.jpg
#   inflating: 29.5163.jpg
#   inflating: 29.5165.jpg
#   inflating: 29.5169.jpg
#   inflating: 29.5185.jpg
#   inflating: 29.5192.jpg
#   inflating: 29.5208.jpg
#   inflating: 29.5226.jpg
#   inflating: 29.5234.jpg
#   inflating: 29.5252.jpg
#   inflating: 29.5271.jpg
#   inflating: 29.5286.jpg
#   inflating: 29.5289.jpg
#   inflating: 29.5291.jpg
#   inflating: 29.5302.jpg
#   inflating: 29.5312.jpg
#   inflating: 29.533.jpg
#   inflating: 29.5339.jpg
#   inflating: 29.5343.jpg
#   inflating: 29.5351.jpg
#   inflating: 29.5364.jpg
#   inflating: 29.5367.jpg
#   inflating: 29.5394.jpg
#   inflating: 29.5422.jpg
#   inflating: 29.5448.jpg
#   inflating: 29.5451.jpg
#   inflating: 29.5465.jpg
#   inflating: 29.547.jpg
#   inflating: 29.5477.jpg
#   inflating: 29.548.jpg
#   inflating: 29.581.jpg
#   inflating: 29.587.jpg
#   inflating: 29.603.jpg
#   inflating: 29.607.jpg
#   inflating: 29.613.jpg
#   inflating: 29.619.jpg
#   inflating: 29.631.jpg
#   inflating: 29.64.jpg
#   inflating: 29.653.jpg
#   inflating: 29.665.jpg
#   inflating: 29.669.jpg
#   inflating: 29.681.jpg
#   inflating: 29.684.jpg
#   inflating: 29.708.jpg
#   inflating: 29.727.jpg
#   inflating: 29.761.jpg
#   inflating: 29.79.jpg
#   inflating: 29.808.jpg
#   inflating: 29.828.jpg
#   inflating: 29.866.jpg
#   inflating: 29.898.jpg
#   inflating: 29.907.jpg
#   inflating: 29.925.jpg
#   inflating: 29.944.jpg
#   inflating: 29.971.jpg
# /content

# %%
# 압축해제된 데이터 경로를 찾아 복사해서 붙여넣어주세요
src = './data_3000/'

# 이미지 읽기 및 출력
def img_read_plot(src,file):
    img = cv.imread(src+file,cv.COLOR_BGR2GRAY)
    plt.imshow(img)
    plt.xticks([]) # x축 눈금
    plt.yticks([]) # y축 눈금
    plt.show()
    return img

#이미지 읽기
def img_read(src,file):
    img = cv.imread(src+file,cv.COLOR_BGR2GRAY)
    return img

#src 경로에 있는 파일 명을 저장합니다.
files = os.listdir(src)

# 경로와 파일명을 입력으로 넣어 확인하고
# 데이터를 255로 나눠서 0~1사이로 정규화 하여 X 리스트에 넣습니다.

X,Y = [],[]
for file in files:
  X.append(img_read(src,file)/255.)
  Y.append(float(file[:-4]))


# Train set, Test set으로 나누기
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size=0.2, random_state=1,shuffle=True)
x_train = np.array(x_train)
x_test = np.array(x_test)


 # (image,image)이미지를 크기의 (image*image,)크기의 벡터로 만듭니다
x_train = x_train.reshape((len(x_train), np.prod(x_train.shape[1:]))).astype('float32')
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:]))).astype('float32')

print("Datasets_train_shape:{}  Datasets_test_shape:{}".format(np.shape(x_train),np.shape(x_test)))
# Out:
# Datasets_train_shape:(2400, 3136)  Datasets_test_shape:(600, 3136)

# %% [markdown]
# VAE 모델만들기

# %%
# network parameters
input_shape = np.shape(x_train[0])[0]
original_dim= input_shape
intermediate_dim = 512
latent_dim = 2

# %%
def encoder():
  # 인코더의 입력층을 생성합니다.
  inputs = Input(shape=(input_shape,), name='input_shape')

  # 인코더의 hidden층을 생성합니다. 500개의 유닛을 사용했습니다.
  encoder_hidden = layers.Dense(intermediate_dim, activation='relu', name='encoder_hidden1')(inputs)

  # 평균(mean)과 표준편차(sigma)층을 정의합니다.
  # 이때 sigma 대신 log variance를 사용합니다. 이는 신경망의 출력은 음수를 가질 수 있지만 sigma는 항상 양수여야 하기 때문입니다.
  # 각각 2개의 유닛을 사용했습니다.
  z_mean = layers.Dense(latent_dim, name='z_mean')(encoder_hidden)
  z_log_var = layers.Dense(latent_dim, name='z_log_var')(encoder_hidden)

  # 평균과 표준편차를 래핑하여 Z_sampling층을 만듭니다.

  # Z 샘플링 함수 생성
  def sampling(args):
      z_mean, z_log_var = args
      batch = shape(z_mean)[0]
      dim = shape(z_mean)[1]

      # by default, random_normal has mean = 0 and std = 1.0
      # Reparameterization Trick사용을 위해 Gussian(=normal)분포에서 랜덤변수(sample) ε추출
      epsilon = tf.compat.v2.random.normal(shape=(batch, dim))
      return z_mean + tf.math.exp(0.5 * z_log_var) * epsilon

  #  layers.Lambda API 래핑에 사용할 함수와, 유닛수(n,)를 지정합니다.
  z_sampling = layers.Lambda(sampling, (latent_dim,), name='z_sample')([z_mean, z_log_var])

  # 하나의 입력과 다중충력을 포함하는 encoder 모델을 만듭니다.
  return Model(inputs,[z_mean,z_log_var,z_sampling], name='encoder')

encoder = encoder()

# 인코더 네트워크를 확인합니다.
encoder.summary()

from tensorflow.keras.utils import plot_model
plot_model(encoder, to_file='vae_mlp_encoder.png', show_shapes=True)
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_shape (InputLayer)       [(None, 3136)]       0           []
#
#  encoder_hidden1 (Dense)        (None, 512)          1606144     ['input_shape[0][0]']
#
#  z_mean (Dense)                 (None, 2)            1026        ['encoder_hidden1[0][0]']
#
#  z_log_var (Dense)              (None, 2)            1026        ['encoder_hidden1[0][0]']
#
#  z_sample (Lambda)              (None, 2)            0           ['z_mean[0][0]',
#                                                                   'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 1,608,196
# Trainable params: 1,608,196
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# Decoder

# %%
def decoder():

  # 디코더의 입력층을 생성합니다. (Decoder의 입력은 latent입니다)
  input_z = Input(shape=(latent_dim,), name='input_z')

  # 디코더의 hidden층을 생성합니다. 인코더와 동일하게 500개의 유닛을 사용했습니다.
  decoder_hidden = layers.Dense(intermediate_dim, activation='relu', name='decoder_hidden')(input_z)

  # 디코더의 출력층은 인코더 입력벡터 수만큼 유닛을 사용합니다.
  outputs = layers.Dense(original_dim, activation='sigmoid',name='output')(decoder_hidden)

  return Model(input_z, outputs, name='decoder')

decoder = decoder()

# 디코더의 네트워크 확인.
decoder.summary()
plot_model(decoder, to_file='vae_mlp_decoder.png', show_shapes=True)
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_z (InputLayer)        [(None, 2)]               0
#
#  decoder_hidden (Dense)      (None, 512)               1536
#
#  output (Dense)              (None, 3136)              1608768
#
# =================================================================
# Total params: 1,610,304
# Trainable params: 1,610,304
# Non-trainable params: 0
# _________________________________________________________________

# %%
def vae():
  # vae는 입력으로 이미지로 들어와 encoder를 통해 z_sampling 되어 decoder로 출력됩니다.
  inputs = Input(shape=(input_shape,), name='input_shape')
  outputs = decoder(encoder(inputs)[2]) #[0]:z_mean, [1]:z_log_var,[2]:z_sampling

  return Model(inputs,outputs, name='vae_mlp')

#VAE 모델 정의
model = vae()

#모델 네트워크 확인
model.summary()
plot_model(model,to_file='vae_mlp.png',show_shapes=True)
# Out:
# Model: "vae_mlp"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_shape (InputLayer)    [(None, 3136)]            0
#
#  encoder (Functional)        [(None, 2),               1608196
#                               (None, 2),
#                               (None, 2)]
#
#  decoder (Functional)        (None, 3136)              1610304
#
# =================================================================
# Total params: 3,218,500
# Trainable params: 3,218,500
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# modelfit

# %%
#Hyperparameters
num_epochs = 100
batch_size = 20
learning_rate = 1e-3

# %%
# 모델 학습 loss, optimizer 정의
adam = tf.keras.optimizers.Adam(learning_rate=learning_rate)
def vae_loss(x,recon_x):
    # (1)Reconstruct loss (Marginal_likelihood) : Cross-entropy
    z_mean,z_log_var,z_sampling = encoder(x)
    recon_x=decoder(z_sampling)
    reconstruction_loss = binary_crossentropy(x,recon_x)
    #reconstruction_loss = mse(inputs, outputs)
    reconstruction_loss *= original_dim
    # (2) KL divergence(Latent_loss)
    kl_loss = 0.5 * tf.reduce_sum(tf.square(z_mean)+ tf.exp(z_log_var)- z_log_var -1, 1)
    return tf.reduce_mean(reconstruction_loss + kl_loss) #ELBO(=VAE_loss)
model.compile(optimizer= adam, loss='mse')

# %%
# 모델 학습
hist = model.fit(x_train, x_train, epochs=num_epochs, batch_size=batch_size)

# 학습된 VAE 모델 저장
model.save_weights('vae_bracket.h5')
# Out:
# Epoch 1/100
# 120/120 [==============================] - 7s 44ms/step - loss: 0.0874
# Epoch 2/100
# 120/120 [==============================] - 5s 44ms/step - loss: 0.0761
# Epoch 3/100
# 120/120 [==============================] - 6s 48ms/step - loss: 0.0737
# Epoch 4/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0703
# Epoch 5/100
# 120/120 [==============================] - 6s 48ms/step - loss: 0.0678
# Epoch 6/100
# 120/120 [==============================] - 5s 45ms/step - loss: 0.0665
# Epoch 7/100
# 120/120 [==============================] - 6s 47ms/step - loss: 0.0659
# Epoch 8/100
# 120/120 [==============================] - 6s 47ms/step - loss: 0.0653
# Epoch 9/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0648
# Epoch 10/100
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0642
# Epoch 11/100
# 120/120 [==============================] - 5s 39ms/step - loss: 0.0640
# Epoch 12/100
# 120/120 [==============================] - 7s 55ms/step - loss: 0.0636
# Epoch 13/100
# 120/120 [==============================] - 5s 44ms/step - loss: 0.0635
# Epoch 14/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0630
# Epoch 15/100
# 120/120 [==============================] - 6s 48ms/step - loss: 0.0634
# Epoch 16/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0631
# Epoch 17/100
# 120/120 [==============================] - 6s 48ms/step - loss: 0.0626
# Epoch 18/100
# 120/120 [==============================] - 5s 41ms/step - loss: 0.0624
# Epoch 19/100
# 120/120 [==============================] - 5s 41ms/step - loss: 0.0623
# Epoch 20/100
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0619
# Epoch 21/100
# 120/120 [==============================] - 5s 39ms/step - loss: 0.0618
# Epoch 22/100
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0616
# Epoch 23/100
# 120/120 [==============================] - 5s 41ms/step - loss: 0.0616
# Epoch 24/100
# 120/120 [==============================] - 5s 41ms/step - loss: 0.0614
# Epoch 25/100
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0614
# Epoch 26/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0613
# Epoch 27/100
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0610
# Epoch 28/100
# 120/120 [==============================] - 5s 42ms/step - loss: 0.0609
# Epoch 29/100
# 120/120 [==============================] - 5s 43ms/step - loss: 0.0610
# Epoch 30/100
# 120/120 [==============================] - 6s 47ms/step - loss: 0.0607
# Epoch 31/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0606
# Epoch 32/100
# 120/120 [==============================] - 6s 48ms/step - loss: 0.0603
# Epoch 33/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0602
# Epoch 34/100
# 120/120 [==============================] - 5s 43ms/step - loss: 0.0602
# Epoch 35/100
# 120/120 [==============================] - 6s 46ms/step - loss: 0.0601
# Epoch 36/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0601
# Epoch 37/100
# 120/120 [==============================] - 8s 69ms/step - loss: 0.0599
# Epoch 38/100
# 120/120 [==============================] - 6s 47ms/step - loss: 0.0600
# Epoch 39/100
# 120/120 [==============================] - 6s 50ms/step - loss: 0.0597
# Epoch 40/100
# 120/120 [==============================] - 5s 41ms/step - loss: 0.0597
# Epoch 41/100
# 120/120 [==============================] - 6s 47ms/step - loss: 0.0595
# Epoch 42/100
# 120/120 [==============================] - 7s 55ms/step - loss: 0.0596
# Epoch 43/100
# 120/120 [==============================] - 5s 39ms/step - loss: 0.0595
# Epoch 44/100
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0593
# Epoch 45/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0594
# Epoch 46/100
# 120/120 [==============================] - 5s 39ms/step - loss: 0.0591
# Epoch 47/100
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0589
# Epoch 48/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0592
# Epoch 49/100
# 120/120 [==============================] - 6s 48ms/step - loss: 0.0591
# Epoch 50/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0588
# Epoch 51/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0587
# Epoch 52/100
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0586
# Epoch 53/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0586
# Epoch 54/100
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0585
# Epoch 55/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0585
# Epoch 56/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0584
# Epoch 57/100
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0585
# Epoch 58/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0583
# Epoch 59/100
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0582
# Epoch 60/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0581
# Epoch 61/100
# 120/120 [==============================] - 5s 41ms/step - loss: 0.0581
# Epoch 62/100
# 120/120 [==============================] - 6s 48ms/step - loss: 0.0584
# Epoch 63/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0582
# Epoch 64/100
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0579
# Epoch 65/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0578
# Epoch 66/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0579
# Epoch 67/100
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0581
# Epoch 68/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0578
# Epoch 69/100
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0576
# Epoch 70/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0575
# Epoch 71/100
# 120/120 [==============================] - 5s 42ms/step - loss: 0.0577
# Epoch 72/100
# 120/120 [==============================] - 7s 59ms/step - loss: 0.0575
# Epoch 73/100
# 120/120 [==============================] - 5s 41ms/step - loss: 0.0575
# Epoch 74/100
# 120/120 [==============================] - 6s 47ms/step - loss: 0.0576
# Epoch 75/100
# 120/120 [==============================] - 5s 42ms/step - loss: 0.0574
# Epoch 76/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0573
# Epoch 77/100
# 120/120 [==============================] - 6s 48ms/step - loss: 0.0576
# Epoch 78/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0574
# Epoch 79/100
# 120/120 [==============================] - 6s 48ms/step - loss: 0.0571
# Epoch 80/100
# 120/120 [==============================] - 5s 42ms/step - loss: 0.0576
# Epoch 81/100
# 120/120 [==============================] - 5s 41ms/step - loss: 0.0574
# Epoch 82/100
# 120/120 [==============================] - 6s 48ms/step - loss: 0.0573
# Epoch 83/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0570
# Epoch 84/100
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0571
# Epoch 85/100
# 120/120 [==============================] - 5s 41ms/step - loss: 0.0569
# Epoch 86/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0570
# Epoch 87/100
# 120/120 [==============================] - 6s 48ms/step - loss: 0.0571
# Epoch 88/100
# 120/120 [==============================] - 5s 39ms/step - loss: 0.0569
# Epoch 89/100
# 120/120 [==============================] - 6s 48ms/step - loss: 0.0570
# Epoch 90/100
# 120/120 [==============================] - 5s 42ms/step - loss: 0.0573
# Epoch 91/100
# 120/120 [==============================] - 5s 41ms/step - loss: 0.0569
# Epoch 92/100
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0568
# Epoch 93/100
# 120/120 [==============================] - 5s 41ms/step - loss: 0.0567
# Epoch 94/100
# 120/120 [==============================] - 6s 48ms/step - loss: 0.0566
# Epoch 95/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0567
# Epoch 96/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0564
# Epoch 97/100
# 120/120 [==============================] - 6s 49ms/step - loss: 0.0563
# Epoch 98/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0565
# Epoch 99/100
# 120/120 [==============================] - 6s 48ms/step - loss: 0.0564
# Epoch 100/100
# 120/120 [==============================] - 5s 40ms/step - loss: 0.0566

# %%
recon_x_test = model.predict(x_test)                #

n = 10  # how many digits we will display
plt.figure(figsize=(15, 4))
for i in range(10):
    # display original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_test[i].reshape(56,56), vmin=0, vmax=1, cmap="gray")
    plt.title("Input"+str(i))
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    #plt.colorbar()

    # display reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(recon_x_test[i].reshape(56, 56),vmin=0, vmax=1, cmap="gray")
    plt.title("Recon"+str(i))
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    #plt.colorbar()
plt.show()
# Out:
# 19/19 [==============================] - 0s 12ms/step

# %%
# 학습모델이 생성한 Manifold를 plot하는 함수 정의
def plot_results(models,
                 data,
                 batch_size=batch_size,
                 model_name="vae_mnist"):
    encoder, decoder = models
    x_test, y_test = data
    filename = "digits_over_latent.png"
    # display a 30x30 2D manifold of digitsa
    n = 10
    digit_size = 56
    figure = np.zeros((digit_size * n, digit_size * n))
    # linearly spaced coordinates corresponding to the 2D plot
    # of digit classes in the latent space
    grid_x = np.linspace(-2, 2, n)
    grid_y = np.linspace(-2, 2, n)[::-1]

    for i, yi in enumerate(grid_y):
        for j, xi in enumerate(grid_x):
            z_sample = np.array([[xi, yi]])
            x_decoded = decoder.predict(z_sample)
            digit = x_decoded[0].reshape(digit_size, digit_size)
            figure[i * digit_size: (i + 1) * digit_size,
                   j * digit_size: (j + 1) * digit_size] = digit

    plt.figure(figsize=(10, 10))
    start_range = digit_size // 2
    end_range = (n - 1) * digit_size + start_range + 1
    pixel_range = np.arange(start_range, end_range, digit_size)
    sample_range_x = np.round(grid_x, 1)
    sample_range_y = np.round(grid_y, 1)
    plt.xticks(pixel_range, sample_range_x)
    plt.yticks(pixel_range, sample_range_y)
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.imshow(figure, cmap='Greys_r')
    plt.savefig(filename)
    plt.show()

plot_results(models = (encoder, decoder),
                 data = (x_test, y_test),
                 batch_size=batch_size,
                 model_name="vae_mlp")
# Out:
# 1/1 [==============================] - 0s 57ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 38ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 55ms/step
# 1/1 [==============================] - 0s 37ms/step
# 1/1 [==============================] - 0s 34ms/step
# 1/1 [==============================] - 0s 44ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 34ms/step

# %%
def tsne_plot_results(models,
                 data,
                 batch_size=128,
                 model_name="vae_mnist"):

    encoder, decoder = models
    x_test, y_test = data
    os.makedirs(model_name, exist_ok=True)

    #filename = os.path.join(model_name, "vae_mean.png")
    filename = "vae_mean.png"
    # display a 2D plot of the digit classes in the latent space
    z_mean, _, _ = encoder.predict(x_test,
                                   batch_size=batch_size)
    plt.figure(figsize=(10, 10))
    plt.scatter(z_mean[:, 0], z_mean[:, 1], c=y_test)
    plt.colorbar()
    plt.xlabel("z[0]")
    plt.ylabel("z[1]")
    plt.savefig(filename)
    plt.show()

tsne_plot_results(models = (encoder, decoder),
                 data = (x_test, y_test),
                 batch_size=batch_size,
                 model_name="vae_mlp")
# Out:
# 30/30 [==============================] - 0s 7ms/step

# %%
def linear_interpolation(x_from, x_to, steps=10):
    n = steps + 1

    t_from = x_from
    t_to = x_to

    diff = t_to - t_from
    inter = np.zeros((n, t_from.shape[0]))
    for i in range(n):
        inter[i] = t_from + i / steps * diff

    return decoder.predict(inter)

# %%
target_a = np.array([1, 1]) # 타겟 시작 좌표
target_b = np.array([10, 10]) # 타겟 끝 좌표
z_decoder_imgs = linear_interpolation(target_a,target_b, 10)
# Out:
# 1/1 [==============================] - 0s 26ms/step

# %%
N = 1
M = 10
img_size= 56
fig = plt.figure(figsize=(10, 10))
plt.subplots_adjust(top=1, bottom=0, hspace=0, wspace=0.05)
for i in range(N):
    for j in range(M):
        k = i * M + j
        ax = fig.add_subplot(N, M, k+1)
        ax.imshow(np.reshape(z_decoder_imgs[k], (img_size, img_size)), cmap=plt.cm.gist_gray)
        ax.grid(False)
        ax.xaxis.set_ticks([])
        ax.yaxis.set_ticks([])
plt.tight_layout()
